# %% [markdown]
# # Data Analysis for Thesis
# ## Step 1 Read Data

# %%
import pandas as pd
import seaborn as sns
articles=pd.read_csv('/Users/chenyuli/Research_Thesis/validate/20210707/20210707_articles.csv'
                    )
# change Journal name to uppercase for future mapping
alphanumeric = ""
for i in range(len(articles.Journal)):
    articles.Journal[i]=articles.Journal[i].upper()
    articles.Journal[i].replace("''", "")
    articles.ISSN[i]=articles.ISSN[i][1:]
# Out:
# /var/folders/v0/r16j2f9545n7rrq_rvqlxn180000gn/T/ipykernel_10893/788572280.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   articles.Journal[i]=articles.Journal[i].upper()
# /var/folders/v0/r16j2f9545n7rrq_rvqlxn180000gn/T/ipykernel_10893/788572280.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   articles.ISSN[i]=articles.ISSN[i][1:]

# %%
articles.head()
# Out:
#    EndNote_ID                                       Article_Name  \
# 0           1                   The "All of Us" Research Program
# 1           2  Evaluation and accurate diagnoses of pediatric...
# 2           3  A large electronic-health-record-based genome-...
# 3           4  Effect of Electronic Health Record-Based Medic...
# 4           5  Prediction of myopia development among Chinese...
#
#                                             Abstract  Year  \
# 0  Knowledge gained from observational cohort stu...  2019
# 1  Artificial intelligence (AI)-based methods hav...  2019
# 2  A genome-wide association study¬†(GWAS) of 94,...  2018
# 3  IMPORTANCE: Complex medication regimens pose s...  2018
# 4  BACKGROUND: Electronic medical records provide...  2018
#
#                            Journal  PubMed_ID Language  \
# 0  NEW ENGLAND JOURNAL OF MEDICINE   31412182      eng
# 1                  NATURE MEDICINE   30742121      eng
# 2                  NATURE GENETICS   29507422      eng
# 3                  JAMA INTERN MED   29987324      eng
# 4                    PLOS MEDICINE   30399150      eng
#
#                                 DOI       ISSN
# 0             10.1056/NEJMsr1809937  0028-4793
# 1         10.1038/s41591-018-0335-9  1078-8956
# 2         10.1038/s41588-018-0064-5  1061-4036
# 3   10.1001/jamainternmed.2018.2372  2168-6106
# 4      10.1371/journal.pmed.1002674  1549-1277

# %%
Years=articles['Year']

# %%
Cal_Year=Years.value_counts().reset_index().rename(columns={'index':'Year','Year':'paper_count'})
Cal_Year
Cal_Year.sort_values('Year')
Cal_Year_graph=Cal_Year[Cal_Year.Year!=2020]

# %% [markdown]
# ## Step 2 Explore data characteristics

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
from matplotlib.ticker import MaxNLocator
from collections import namedtuple

# %%
plt.rcdefaults()
fig, g1 = plt.subplots(figsize=(8, 6))
g1 .bar('Year','paper_count',data=Cal_Year_graph,color="gray",align='center')

#g1.set_title("Paper Extracted from PubMed by Year")
plt.ylabel("Paper Count")
plt.xlabel("Years")
g1.set_xticks(Cal_Year_graph.Year)
for a,b in zip(Cal_Year_graph.Year,Cal_Year_graph.paper_count):
    g1.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=9)
plt.title('Published Papers Extracted from PubMed by Year')
plt.show()

# %%
paper_2010=list(articles[articles.Year==2010].EndNote_ID)
paper_2011=list(articles[articles.Year==2011].EndNote_ID)
paper_2012=list(articles[articles.Year==2012].EndNote_ID)
paper_2013=list(articles[articles.Year==2013].EndNote_ID)
paper_2014=list(articles[articles.Year==2014].EndNote_ID)
paper_2015=list(articles[articles.Year==2015].EndNote_ID)
paper_2016=list(articles[articles.Year==2016].EndNote_ID)
paper_2017=list(articles[articles.Year==2017].EndNote_ID)
paper_2018=list(articles[articles.Year==2018].EndNote_ID)
paper_2019=list(articles[articles.Year==2019].EndNote_ID)

# %%
len(paper_2010+paper_2011+paper_2012+paper_2013)
# Out:
# 1237

# %%
len(paper_2014+paper_2015+paper_2016)
# Out:
# 1679

# %%
len(paper_2017)
# Out:
# 815

# %%
len(paper_2018)
# Out:
# 979

# %%
len(paper_2019)
# Out:
# 1104

# %% [markdown]
# ## Step 3 Take Sample Papers to Read

# %%
# import package random, sample 300 papers per epoch. 
import random
import pandas as pd
random.seed(2020)
sp2010_2013=random.sample(paper_2010+paper_2011+paper_2012+paper_2013,300)
sp2014_2016=random.sample(paper_2014+paper_2015+paper_2016,300)
sp2017=random.sample(paper_2017,300)
sp2018=random.sample(paper_2018,300)
sp2019=random.sample(paper_2019,300)

# %%
article_list=[sp2010_2013,sp2014_2016,sp2017,sp2018,sp2019]
article_df=pd.DataFrame(article_list)

# %%
article_df=article_df.rename(index={0:'2010-2013',1:'2014-2016',2:'2017',3:'2018',4:'2019'})
article_df.index
# sample article index_number we need to get articles from the list until reach 35 articles we include.
# Out:
# Index(['2010-2013', '2014-2016', '2017', '2018', '2019'], dtype='object')

# %% [markdown]
# ### Sample papers by Epochs

# %%
Samples_2010_2013=article_df.iloc[0,0:300]
#Samples_2010_2013[49:100]
Samples_2014_2016=article_df.iloc[1,0:300]
#Samples_2014_2016[49:100]
Samples_2017=article_df.iloc[2,0:300]
#Samples_2017[50:100]
Samples_2018=article_df.iloc[3,0:300]
#Samples_2018[50:100]
Samples_2019=article_df.iloc[4,0:300]
#Samples_2019[49:101]

# %%
# check repeat number    
import pandas as pd
df2014_2016=pd.DataFrame(sp2014_2016)
df2010_2013=pd.DataFrame(sp2010_2013)
df2017=pd.DataFrame(sp2017)

# %%
# save the sampled article pool 
article_df.to_csv('Sampled_EndnoteId',index=True)

# %%
articles.Journal.value_counts()
# Out:
# PLOS ONE                                                   133
# BMJ OPEN                                                   131
# JOURNAL OF THE AMERICAN MEDICAL INFORMATICS ASSOCIATION     69
# PHARMACOEPIDEMIOLOGY AND DRUG SAFETY                        63
# J TRAUMA ACUTE CARE SURG                                    56
#                                                           ...
# THER INNOV REGUL SCI                                         1
# KYOBU GEKA JAPANESE JOURNAL OF THORACIC SURGERY              1
# FORSCH KOMPLEMENTMED                                         1
# ARQUIVOS BRASILEIROS DE CARDIOLOGIA                          1
# JOURNAL OF MEDICAL GENETICS                                  1
# Name: Journal, Length: 1404, dtype: int64

# %%
Journal_list=articles.Journal.value_counts().reset_index().rename(columns={'index':'Journal_name','Journal':'paper_count'})

# %%
Top_10=Journal_list.head(10)
Top_10
# Out:
#                                         Journal_name  paper_count
# 0                                           PLOS ONE          133
# 1                                           BMJ OPEN          131
# 2  JOURNAL OF THE AMERICAN MEDICAL INFORMATICS AS...           69
# 3               PHARMACOEPIDEMIOLOGY AND DRUG SAFETY           63
# 4                           J TRAUMA ACUTE CARE SURG           56
# 5                   AMERICAN JOURNAL OF MANAGED CARE           53
# 6       INTERNATIONAL JOURNAL OF MEDICAL INFORMATICS           52
# 7                       BMC HEALTH SERVICES RESEARCH           48
# 8        BMC MEDICAL INFORMATICS AND DECISION MAKING           43
# 9               JOURNAL OF MEDICAL INTERNET RESEARCH           40

# %% [markdown]
# ## Plot Papers by Journal

# %%
import seaborn
import matplotlib.pyplot as plt
Top_10.sort_values('paper_count',inplace=True)
plt.barh(Top_10.Journal_name,Top_10.paper_count,align='center')
#plt.xticks(rotaion=45)
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# <BarContainer object of 10 artists>

# %% [markdown]
# ## Step 4 Interrater Reliability Check

# %% [markdown]
# #### Select 20 papers for second reader to annotate/ May 31st 2020
# Second reviewer reviewed the test cohort 1 list, inter-rater reliability was calculated based on test cohort.

# %% [markdown]
# ## Step 5  Analyze Included Papers
#
# 07_07_2021

# %%
Article_Review=pd.read_csv('/Users/chenyuli/Research_Thesis/Validate/20210707/Validated_Article_Review.csv')
AR_Include=Article_Review[Article_Review.Include_in_Research=='Yes']
AR_Include
# Out:
#      Review_ID  included_No  Reviewer_ID  EndNote_Index  Pubmed_ID  Year  \
# 4          5.0          1.0          NaN           3197   31167871  2019
# 10        11.0          2.0          NaN           1259   31306445  2019
# 11        12.0          3.0          NaN           1538   31881945  2019
# 12        13.0          4.0          NaN           3304   31332959  2019
# 14        15.0          5.0          NaN           1717   31210654  2019
# ..         ...          ...          ...            ...        ...   ...
# 380      381.0         31.0          NaN           4917   22871081  2012
# 386      387.0         32.0          NaN           5805   23756616  2013
# 388      389.0         33.0          NaN           3587   22484068  2013
# 390      391.0         34.0          NaN           4342   21801091  2011
# 391      392.0         35.0          NaN           5790   23165956  2013
#
#                                           Article_Name Review_Date  \
# 4    Trends in the incidence of testing for vitamin...    12/27/20
# 10   An interactive nomogram to predict healthcare-...    12/27/20
# 11   Sex differences in 10-year ischemic cardiovasc...    12/27/20
# 12   Clinical outcomes of external beam radiotherap...    12/27/20
# 14   Preoperative Pulmonary Function Test Results A...    12/27/20
# ..                                                 ...         ...
# 380  Likelihood of acute coronary syndrome in emerg...      7/7/21
# 386  Synchronization of administrations of chemothe...      7/7/21
# 388  Comparisons of 30-day mortalities and 90-day f...      7/7/21
# 390  Risk factors for emergent preterm delivery in ...      7/7/21
# 391  Zolpidem is independently associated with incr...      7/7/21
#
#        First_Author                                          Key_words  ...  \
# 4      Crowe, F. L.  Adult\nAged\nEthnic Groups\nFemale\nHumans\nIn...  ...
# 10        Zhang, M.  Acinetobacter Infections/diagnosis/epidemiolog...  ...
# 11         Yang, L.  Aged\nChina/epidemiology\nComorbidity\nDatabas...  ...
# 12       Lee, C. C.  Aged\nFollow-Up Studies\nHumans\nMale\nMiddle ...  ...
# 14    Burjek, N. E.  ng/*physiopathology\nMale\nMaximal Respiratory...  ...
# ..              ...                                                ...  ...
# 380     Ekelund, U.  Acute Coronary Syndrome/*complications/*diagno...  ...
# 386     Hill, J. W.  Adolescent\nAdult\nAged\nAmbulatory Care Facil...  ...
# 388      Kim, K. H.  Adult\nAged\nAged, 80 and over\nBody Mass Inde...  ...
# 390  Fishman, S. G.  Adult\nCohort Studies\nFemale\nGestational Age...  ...
# 391    Kolla, B. P.  Accidental Falls/*statistics & numerical data\...  ...
#
#     Association_Type Unit_of_Analysis Check_List   Mention_Missing_Data  \
# 4        Asosciation          patient         No        Yes, limitation
# 10       Association          Patient         No                     No
# 11       Association          patient         No                     No
# 12       Association          Patient         No                     No
# 14       Association          Patient         No                     No
# ..               ...              ...        ...                    ...
# 380      Associaiton          Patient         No     Yes, data cleaning
# 386      Association          Patient         No  Yes, data description
# 388      Association          Patient         No                     No
# 390      Associaiton          Patient         No                     No
# 391      Associaiton          Patient         No                     No
#
#     Assessed_Missing_Data Rate_of_Article Include_in_Research  \
# 4                      No             NaN                 Yes
# 10                     No             NaN                 Yes
# 11                     No             NaN                 Yes
# 12                     No             NaN                 Yes
# 14                     No             NaN                 Yes
# ..                    ...             ...                 ...
# 380         Yes, excluded             NaN                 Yes
# 386                    No             NaN                 Yes
# 388                    No             NaN                 Yes
# 390                    No             NaN                 Yes
# 391                    No             NaN                 Yes
#
#     Exclusion Reason  Other_Notes Unnamed: 28
# 4                NaN          NaN         NaN
# 10               NaN          NaN         NaN
# 11               NaN          NaN         NaN
# 12               NaN          NaN         NaN
# 14               NaN          NaN         NaN
# ..               ...          ...         ...
# 380              NaN          NaN         NaN
# 386              NaN          NaN         NaN
# 388              NaN          NaN         NaN
# 390              NaN          NaN         NaN
# 391              NaN          NaN         NaN
#
# [175 rows x 29 columns]

# %%
# 07/12/add Journal analysis 
Included_list_Journal=articles[articles.EndNote_ID.isin(AR_Include.EndNote_Index)].Journal.value_counts().reset_index().rename(columns={'index':'Journal_name','Journal':'paper_count'})
Included_list_Journal
# Out:
#                          Journal_name  paper_count
# 0                            BMJ OPEN            5
# 1                            PLOS ONE            4
# 2    ANNALS OF THE RHEUMATIC DISEASES            3
# 3               MATERN CHILD HEALTH J            2
# 4                  WORLD NEUROSURGERY            2
# ..                                ...          ...
# 140                           SURGERY            1
# 141                      SCAND J UROL            1
# 142                PEDIATRIC DIABETES            1
# 143        PREVENTING CHRONIC DISEASE            1
# 144              CLINICAL LUNG CANCER            1
#
# [145 rows x 2 columns]

# %%
I_Top_10=Included_list_Journal.head(10)
I_Top_10.sort_values('paper_count',inplace=True)
plt.barh(I_Top_10.Journal_name,I_Top_10.paper_count,align='center')
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# <BarContainer object of 10 artists>

# %%
# included papers 
I_Papers=articles[articles['EndNote_ID'].isin(AR_Include.EndNote_Index)]
I_Papers
# Out:
#       EndNote_ID                                       Article_Name  \
# 421          422  Evaluation of the quality of antenatal care us...
# 689          690  The effectiveness of varenicline versus nicoti...
# 690          691  Development and validation of an ICD-10-based ...
# 699          700  Cost Savings from Reducing Pain Through the De...
# 729          730  The clinical epidemiology of fatigue in newly ...
# ...          ...                                                ...
# 5782        5783  Association Between Positive Cultures During A...
# 5789        5790  Zolpidem is independently associated with incr...
# 5791        5792  Racial/ethnic differences in the prevalence of...
# 5804        5805  Synchronization of administrations of chemothe...
# 5832        5833  Comparative Effectiveness and Resource Usage i...
#
#                                                Abstract  Year  \
# 421   BACKGROUND: Evaluation of the quality of anten...  2014
# 689   BACKGROUND: There is limited evidence about th...  2017
# 690   BACKGROUND: There was no established disabilit...  2018
# 699   OBJECTIVES: An important task facing hospitals...  2018
# 729   BACKGROUND: Fatigue is a common and distressin...  2017
# ...                                                 ...   ...
# 5782  The number of patients with cancer being admit...  2018
# 5789  BACKGROUND: Inpatient falls are associated wit...  2013
# 5791  OBJECTIVE: To examine racial/ethnic difference...  2013
# 5804  PURPOSE: The erythropoiesis-stimulating agents...  2013
# 5832  BACKGROUND: Weekly (qw) nanoparticle albumin-b...  2017
#
#                                                 Journal  PubMed_ID Language  \
# 421                        BMC PREGNANCY AND CHILDBIRTH   24885103      eng
# 689               INTERNATIONAL JOURNAL OF EPIDEMIOLOGY   29040555      eng
# 690                                              INJURY   29352592      eng
# 699   JOURNAL OF ALTERNATIVE AND COMPLEMENTARY MEDICINE   29474095      eng
# 729                        BMC CARDIOVASCULAR DISORDERS   28490326      eng
# ...                                                 ...        ...      ...
# 5782                                     CANCER CONTROL   30086666      eng
# 5789                       JOURNAL OF HOSPITAL MEDICINE   23165956      eng
# 5791                                      DIABETES CARE   23238659      eng
# 5804                          SUPPORTIVE CARE IN CANCER   23756616      eng
# 5832                               CLINICAL LUNG CANCER   28117221      eng
#
#                                 DOI       ISSN
# 421        10.1186/1471-2393-14-168  1471-2393
# 689              10.1093/ije/dyx109  0300-5771
# 690    10.1016/j.injury.2017.12.021  0020-1383
# 699           10.1089/acm.2017.0203  1075-5535
# 729       10.1186/s12872-017-0555-9  1471-2261
# ...                             ...        ...
# 5782       10.1177/1073274818794162  1073-2748
# 5789               10.1002/jhm.1985  1553-5592
# 5791              10.2337/dc12-0951  0149-5992
# 5804      10.1007/s00520-013-1830-7  0941-4355
# 5832     10.1016/j.cllc.2016.12.008  1525-7304
#
# [175 rows x 9 columns]

# %%
I_Years=I_Papers['Year']
I_Years_Count=I_Years.value_counts().reset_index().rename(columns={'index':'Year','Year':'included_number'}).sort_values('Year').reset_index()
I_Years_Count['epoch']=['epoch 1','epoch 1','epoch 1','epoch 1','epoch 2','epoch 2','epoch 2','epoch 3','epoch 4','epoch 5']
I_Years_Count
# Out:
#    index  Year  included_number    epoch
# 0      9  2010                4  epoch 1
# 1      6  2011                9  epoch 1
# 2      8  2012                6  epoch 1
# 3      4  2013               16  epoch 1
# 4      7  2014                7  epoch 2
# 5      5  2015               11  epoch 2
# 6      3  2016               17  epoch 2
# 7      0  2017               35  epoch 3
# 8      1  2018               35  epoch 4
# 9      2  2019               35  epoch 5

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Plot out Included Papers by Year 
fig, g2 = plt.subplots(figsize=(8, 6))
#g2.bar(I_Years_Count.Year,I_Years_Count.included_number,color="gray",align='center')
I_Years_Count['hatches'] = ['/', '/', '/', '/', '//', '//','//', '///', '////', '/////']
I_Years_Count['colors']=['#08519c','#08519c','#08519c','#08519c',
                        '#3182bd','#3182bd','#3182bd',
                        '#6baed6',
                        '#bdd7e7',
                        '#eff3ff']

print(I_Years_Count)
bars=g2.bar(I_Years_Count.Year,I_Years_Count.included_number,color=I_Years_Count.colors,align='center',label=I_Years_Count.epoch)

plt.ylabel("Paper Count")
plt.xlabel("Years")
g2.set_xticks(I_Years_Count.Year)
plt.title("Included Papers by Year")
for bar, hatch in zip(bars, I_Years_Count.hatches):  # loop over bars and hatches to set hatches in correct order
    bar.set_hatch(hatch)
for a,b in zip(I_Years_Count.Year,I_Years_Count.included_number):# add number on each bar 
    g2.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=9)

handles, labels = g2.get_legend_handles_labels()
labels=I_Years_Count.epoch
plt.legend([handles[0][0],handles[0][5],handles[0][8],handles[0][8],handles[0][9]], labels[[0,5,7,8,9]], loc='upper left')

plt.show()

#color & satuation the same group
# Out:
#    index  Year  included_number    epoch hatches   colors
# 0      9  2010                4  epoch 1       /  #08519c
# 1      6  2011                9  epoch 1       /  #08519c
# 2      8  2012                6  epoch 1       /  #08519c
# 3      4  2013               16  epoch 1       /  #08519c
# 4      7  2014                7  epoch 2      //  #3182bd
# 5      5  2015               11  epoch 2      //  #3182bd
# 6      3  2016               17  epoch 2      //  #3182bd
# 7      0  2017               35  epoch 3     ///  #6baed6
# 8      1  2018               35  epoch 4    ////  #bdd7e7
# 9      2  2019               35  epoch 5   /////  #eff3ff

# %% [markdown]
# #### Extract Journals from included literature

# %%
I_Journal=I_Papers.Journal.value_counts().reset_index().rename(columns={'index':'Journal_name','Journal':'paper_count'})
I_Journal
I_Top_10=I_Journal.head(10).sort_values('paper_count')
plt.barh(I_Top_10.Journal_name,I_Top_10.paper_count,align='center')
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# Extracted Journal Inpact factor information from Clarivate Journal Citation Report dataset( updated on June 30, 2021). https://jcr.clarivate.com/jcr/browse-journals
# Added Filter on 26,674 journals
# Categories:
# * Critical Care Medicine,
# * Engineering, Biomedical,
# * Medical Informatics,
# * Medicine, General & Internal,
# * Medicine, Research & Experimental,
# * Social Sciences, Biomedical,
# * Public, Environmental & Occupational Health,
# * Pediatrics
# * Geriatrics & Gerontology
# * Allergy
# * Multidisciplinary Sciences
# * Emergency Medicine
# * Gastroenterology & Hepatology
# * Surgery
# * Anesthesiology
# * Rheumatology
# * Oncology
# * Orthopedics
# * Pharmacology & Pharmacy
# * Transplantation
# * Cardiac & Cardiovascular Systems
# * ENDOCRINOLOGY & METABOLISM
# * HEALTH CARE SCIENCES & SERVICES
# * OBSTETRICS & GYNECOLOGY
# * DERMATOLOGY
# * UROLOGY & NEPHROLOGY
# * OPHTHALMOLOGY
# *
# Citation Indexes:
# * Science Citation Index Expanded (SCIE)
# * Social Science Citation Index (SSCI)
# * Arts & Humanities Citation Index (AHCI)
# * Emerging Sources Citation Index (ESCI)
# get 728+376+176+66+37 Journals

# %%
Journal_impact=pd.read_csv('/Users/chenyuli/Research_Thesis/Validate/20210707/ChenyuLi_JCR_JournalResults_07_2021.csv',header=0, encoding='unicode_escape')

# change Journal name to upper case -> for future journal impact mappin
for i in range(len(Journal_impact.Journal_name)):
    Journal_impact.Journal_name[i]=Journal_impact.Journal_name[i].upper()

Journal_impact
# Out:
# /var/folders/v0/r16j2f9545n7rrq_rvqlxn180000gn/T/ipykernel_10893/2224448575.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Journal_impact.Journal_name[i]=Journal_impact.Journal_name[i].upper()
#       ï»¿_ID                                       Journal_name       ISSN  \
# 0          1                        LANCET RESPIRATORY MEDICINE  2213-2600
# 1          2                      NATURE BIOMEDICAL ENGINEERING  2157-846X
# 2          3  AMERICAN JOURNAL OF RESPIRATORY AND CRITICAL C...  1073-449X
# 3          4                            INTENSIVE CARE MEDICINE  0342-4642
# 4          5                                BIOACTIVE MATERIALS        NaN
# ...      ...                                                ...        ...
# 4730    4731  JOURNAL OF THE ASEAN FEDERATION OF ENDOCRINE S...  0857-1074
# 4731    4732  AUSTRIAN JOURNAL OF CLINICAL ENDOCRINOLOGY AND...  1998-7773
# 4732    4733  DIABETES & METABOLIC SYNDROME-CLINICAL RESEARC...  1871-4021
# 4733    4734  REVISTA PORTUGUESA DE ENDOCRINOLOGIA DIABETES ...  1646-3439
# 4734    4735  CANADIAN JOURNAL OF RESPIRATORY CRITICAL CARE ...  2474-5332
#
#           eISSN                           Category Total_Citations 2020_JIF  \
# 0           NaN      CRITICAL CARE MEDICINE - SCIE          22,278    30.70
# 1     2157-846X     ENGINEERING, BIOMEDICAL - SCIE           6,476    25.67
# 2     1535-4970      CRITICAL CARE MEDICINE - SCIE          76,608    21.41
# 3     1432-1238      CRITICAL CARE MEDICINE - SCIE          33,510    17.44
# 4     2452-199X     ENGINEERING, BIOMEDICAL - SCIE           2,145    14.59
# ...         ...                                ...             ...      ...
# 4730  2308-118X  ENDOCRINOLOGY & METABOLISM - ESCI              43      NaN
# 4731  1998-7781  ENDOCRINOLOGY & METABOLISM - ESCI              16      NaN
# 4732  1878-0334  ENDOCRINOLOGY & METABOLISM - ESCI           5,270      NaN
# 4733  1646-3439  ENDOCRINOLOGY & METABOLISM - ESCI              45      NaN
# 4734  2474-5340          RESPIRATORY SYSTEM - ESCI             131      NaN
#
#      JIF_Quartile  2020 _JCI Percentage_of_OA_Gold
# 0              Q1       6.48                10.36%
# 1              Q1       5.42                 0.80%
# 2              Q1       4.09                11.41%
# 3              Q1       3.08                20.89%
# 4              Q1       1.69               100.00%
# ...           ...        ...                   ...
# 4730          NaN       0.03               100.00%
# 4731          NaN       0.03                58.57%
# 4732          NaN       0.51                 0.20%
# 4733          NaN       0.01                 0.00%
# 4734          NaN       0.21                 1.35%
#
# [4735 rows x 10 columns]

# %%
Journal_impact
# Out:
#       ï»¿_ID                                       Journal_name       ISSN  \
# 0          1                        LANCET RESPIRATORY MEDICINE  2213-2600
# 1          2                      NATURE BIOMEDICAL ENGINEERING  2157-846X
# 2          3  AMERICAN JOURNAL OF RESPIRATORY AND CRITICAL C...  1073-449X
# 3          4                            INTENSIVE CARE MEDICINE  0342-4642
# 4          5                                BIOACTIVE MATERIALS        NaN
# ...      ...                                                ...        ...
# 4730    4731  JOURNAL OF THE ASEAN FEDERATION OF ENDOCRINE S...  0857-1074
# 4731    4732  AUSTRIAN JOURNAL OF CLINICAL ENDOCRINOLOGY AND...  1998-7773
# 4732    4733  DIABETES & METABOLIC SYNDROME-CLINICAL RESEARC...  1871-4021
# 4733    4734  REVISTA PORTUGUESA DE ENDOCRINOLOGIA DIABETES ...  1646-3439
# 4734    4735  CANADIAN JOURNAL OF RESPIRATORY CRITICAL CARE ...  2474-5332
#
#           eISSN                           Category Total_Citations 2020_JIF  \
# 0           NaN      CRITICAL CARE MEDICINE - SCIE          22,278    30.70
# 1     2157-846X     ENGINEERING, BIOMEDICAL - SCIE           6,476    25.67
# 2     1535-4970      CRITICAL CARE MEDICINE - SCIE          76,608    21.41
# 3     1432-1238      CRITICAL CARE MEDICINE - SCIE          33,510    17.44
# 4     2452-199X     ENGINEERING, BIOMEDICAL - SCIE           2,145    14.59
# ...         ...                                ...             ...      ...
# 4730  2308-118X  ENDOCRINOLOGY & METABOLISM - ESCI              43      NaN
# 4731  1998-7781  ENDOCRINOLOGY & METABOLISM - ESCI              16      NaN
# 4732  1878-0334  ENDOCRINOLOGY & METABOLISM - ESCI           5,270      NaN
# 4733  1646-3439  ENDOCRINOLOGY & METABOLISM - ESCI              45      NaN
# 4734  2474-5340          RESPIRATORY SYSTEM - ESCI             131      NaN
#
#      JIF_Quartile  2020 _JCI Percentage_of_OA_Gold
# 0              Q1       6.48                10.36%
# 1              Q1       5.42                 0.80%
# 2              Q1       4.09                11.41%
# 3              Q1       3.08                20.89%
# 4              Q1       1.69               100.00%
# ...           ...        ...                   ...
# 4730          NaN       0.03               100.00%
# 4731          NaN       0.03                58.57%
# 4732          NaN       0.51                 0.20%
# 4733          NaN       0.01                 0.00%
# 4734          NaN       0.21                 1.35%
#
# [4735 rows x 10 columns]

# %%
Journal_list=articles.Journal
#Journal_list
#match_name=Journal_impact[Journal_impact.Journal_name.isin(I_Journal.Journal_name)]
#match.count()
match_ISSN=Journal_impact[Journal_impact.ISSN.isin(I_Papers.ISSN)]
match_ISSN.count()
# Out:
# ï»¿_ID                   181
# Journal_name             181
# ISSN                     181
# eISSN                    175
# Category                 181
# Total_Citations          181
# 2020_JIF                 180
# JIF_Quartile             180
# 2020 _JCI                181
# Percentage_of_OA_Gold    181
# dtype: int64

# %%
Match_Impact=I_Papers.merge(Journal_impact,how='left',on='ISSN')
Match_Impact
# duplicates are because of In Journal_Impact, there could be one journal name map to different category->as different record.
# Out:
#      EndNote_ID                                       Article_Name  \
# 0           422  Evaluation of the quality of antenatal care us...
# 1           690  The effectiveness of varenicline versus nicoti...
# 2           691  Development and validation of an ICD-10-based ...
# 3           691  Development and validation of an ICD-10-based ...
# 4           691  Development and validation of an ICD-10-based ...
# ..          ...                                                ...
# 254        5792  Racial/ethnic differences in the prevalence of...
# 255        5792  Racial/ethnic differences in the prevalence of...
# 256        5805  Synchronization of administrations of chemothe...
# 257        5805  Synchronization of administrations of chemothe...
# 258        5833  Comparative Effectiveness and Resource Usage i...
#
#                                               Abstract  Year  \
# 0    BACKGROUND: Evaluation of the quality of anten...  2014
# 1    BACKGROUND: There is limited evidence about th...  2017
# 2    BACKGROUND: There was no established disabilit...  2018
# 3    BACKGROUND: There was no established disabilit...  2018
# 4    BACKGROUND: There was no established disabilit...  2018
# ..                                                 ...   ...
# 254  OBJECTIVE: To examine racial/ethnic difference...  2013
# 255  OBJECTIVE: To examine racial/ethnic difference...  2013
# 256  PURPOSE: The erythropoiesis-stimulating agents...  2013
# 257  PURPOSE: The erythropoiesis-stimulating agents...  2013
# 258  BACKGROUND: Weekly (qw) nanoparticle albumin-b...  2017
#
#                                    Journal  PubMed_ID Language  \
# 0             BMC PREGNANCY AND CHILDBIRTH   24885103      eng
# 1    INTERNATIONAL JOURNAL OF EPIDEMIOLOGY   29040555      eng
# 2                                   INJURY   29352592      eng
# 3                                   INJURY   29352592      eng
# 4                                   INJURY   29352592      eng
# ..                                     ...        ...      ...
# 254                          DIABETES CARE   23238659      eng
# 255                          DIABETES CARE   23238659      eng
# 256              SUPPORTIVE CARE IN CANCER   23756616      eng
# 257              SUPPORTIVE CARE IN CANCER   23756616      eng
# 258                   CLINICAL LUNG CANCER   28117221      eng
#
#                                DOI       ISSN  ï»¿_ID  \
# 0         10.1186/1471-2393-14-168  1471-2393     NaN
# 1               10.1093/ije/dyx109  0300-5771  1150.0
# 2     10.1016/j.injury.2017.12.021  0020-1383    85.0
# 3     10.1016/j.injury.2017.12.021  0020-1383   280.0
# 4     10.1016/j.injury.2017.12.021  0020-1383   445.0
# ..                             ...        ...     ...
# 254              10.2337/dc12-0951  0149-5992  3137.0
# 255              10.2337/dc12-0951  0149-5992  4467.0
# 256      10.1007/s00520-013-1830-7  0941-4355  2528.0
# 257      10.1007/s00520-013-1830-7  0941-4355  3600.0
# 258     10.1016/j.cllc.2016.12.008  1525-7304  2467.0
#
#                                           Journal_name      eISSN  \
# 0                                                  NaN        NaN
# 1                INTERNATIONAL JOURNAL OF EPIDEMIOLOGY  1464-3685
# 2    INJURY-INTERNATIONAL JOURNAL OF THE CARE OF TH...  1879-0267
# 3    INJURY-INTERNATIONAL JOURNAL OF THE CARE OF TH...  1879-0267
# 4    INJURY-INTERNATIONAL JOURNAL OF THE CARE OF TH...  1879-0267
# ..                                                 ...        ...
# 254                                      DIABETES CARE  1935-5548
# 255                                      DIABETES CARE  1935-5548
# 256                          SUPPORTIVE CARE IN CANCER  1433-7339
# 257                          SUPPORTIVE CARE IN CANCER  1433-7339
# 258                               CLINICAL LUNG CANCER  1938-0690
#
#                                               Category Total_Citations  \
# 0                                                  NaN             NaN
# 1    PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH - ...          30,944
# 2                        CRITICAL CARE MEDICINE - SCIE          19,692
# 3                        CRITICAL CARE MEDICINE - SCIE             500
# 4                        CRITICAL CARE MEDICINE - SCIE          19,692
# ..                                                 ...             ...
# 254                  ENDOCRINOLOGY & METABOLISM - SCIE          85,997
# 255                  ENDOCRINOLOGY & METABOLISM - SCIE          85,997
# 256                                    ONCOLOGY - SCIE          18,289
# 257             HEALTH CARE SCIENCES & SERVICES - SCIE          18,289
# 258                                    ONCOLOGY - SCIE           4,202
#
#     2020_JIF JIF_Quartile  2020 _JCI Percentage_of_OA_Gold
# 0        NaN          NaN        NaN                   NaN
# 1       7.20           Q1       2.70                41.02%
# 2       2.59           Q3       0.86                 4.88%
# 3       0.87          7.8       8.80                   434
# 4       2.59           Q3       0.86                 4.88%
# ..       ...          ...        ...                   ...
# 254    19.11           Q1       3.63                 0.20%
# 255    19.11           Q1       3.63                 0.20%
# 256     3.60           Q3       1.12                14.60%
# 257     3.60           Q2       1.12                14.60%
# 258     4.79           Q2       0.89                12.99%
#
# [259 rows x 18 columns]

# %%
#check mapped test 
mapped=I_Papers.merge(Journal_impact,how='inner',on='ISSN').sort_values("2020_JIF",ascending=False)
mapped
# Out:
#      EndNote_ID                                       Article_Name  \
# 157        4012  Long-term outcomes of endoscopic resection and...
# 38         1506  Recurrent antibiotic exposure may promote canc...
# 217        5661  Hospital Utilization Among Rural Children Serv...
# 64         2012  The Diagnosis-Wide Landscape of Hospital-Acqui...
# 65         2012  The Diagnosis-Wide Landscape of Hospital-Acqui...
# ..          ...                                                ...
# 48         1812  Effectiveness, safety and costs of thromboembo...
# 89         2696  Abdominal and Pelvic Vascular Injury: A Nation...
# 214        5567  Comparison of intraoperative basal fluid requi...
# 160        4086  Achieving serum urate goal: a comparative effe...
# 114        3115  Elevated Triglycerides (‚â•150 mg/dL) and High...
#
#                                               Abstract  Year  \
# 157  BACKGROUND AND AIMS: Endoscopic resection (ER)...  2019
# 38   BACKGROUND: Bacterial dysbiosis was previously...  2015
# 217  IMPORTANCE: Telemedicine is increasingly used ...  2019
# 64   BACKGROUND AND OBJECTIVES: The exploration of ...  2017
# 65   BACKGROUND AND OBJECTIVES: The exploration of ...  2017
# ..                                                 ...   ...
# 48   PURPOSE: Atrial fibrillation is the most commo...  2016
# 89   The aim of this study was to characterize the ...  2019
# 214  There has been recent progress in intraoperati...  2017
# 160  BACKGROUND: Febuxostat is recommended as 1 of ...  2014
# 114  PURPOSE: Real-world data may provide insight i...  2019
#
#                                                Journal  PubMed_ID Language  \
# 157                         GASTROINTESTINAL ENDOSCOPY   30576649      eng
# 38                          EUROPEAN JOURNAL OF CANCER   26338196      eng
# 217                                     JAMA NETW OPEN   31418803      eng
# 64   CLINICAL JOURNAL OF THE AMERICAN SOCIETY OF NE...   28495862      eng
# 65   CLINICAL JOURNAL OF THE AMERICAN SOCIETY OF NE...   28495862      eng
# ..                                                 ...        ...      ...
# 48                                            BMJ OPEN   26823179      eng
# 89                                    AMERICAN SURGEON   30947777      eng
# 214                               MEDICINE (BALTIMORE)   29381975      eng
# 160                              POSTGRADUATE MEDICINE   24685969      eng
# 114                             VASC HEALTH RISK MANAG   31824165      eng
#
#                                     DOI       ISSN  ï»¿_ID  \
# 157           10.1016/j.gie.2018.12.010  0016-5107    1932
# 38           10.1016/j.ejca.2015.08.015  0959-8049    2387
# 217   10.1001/jamanetworkopen.2019.9364  2574-3805     504
# 64                 10.2215/cjn.10981016  1555-9041    3899
# 65                 10.2215/cjn.10981016  1555-9041    4106
# ..                                  ...        ...     ...
# 48          10.1136/bmjopen-2015-010144  2044-6055     262
# 89                                       0003-1348    2217
# 214         10.1097/md.0000000000008763  0025-7974     357
# 160            10.3810/pgm.2014.03.2741  0032-5481     176
# 114                10.2147/vhrm.S221289  1176-6344    4443
#
#                                           Journal_name      eISSN  \
# 157                         GASTROINTESTINAL ENDOSCOPY  1097-6779
# 38                          EUROPEAN JOURNAL OF CANCER  1879-0852
# 217                                  JAMA NETWORK OPEN  2574-3805
# 64   CLINICAL JOURNAL OF THE AMERICAN SOCIETY OF NE...  1555-905X
# 65   CLINICAL JOURNAL OF THE AMERICAN SOCIETY OF NE...  1555-905X
# ..                                                 ...        ...
# 48                                            BMJ OPEN  2044-6055
# 89                                    AMERICAN SURGEON  1555-9823
# 214                                           MEDICINE  1536-5964
# 160                              POSTGRADUATE MEDICINE  1941-9260
# 114                VASCULAR HEALTH AND RISK MANAGEMENT  1178-2048
#
#                                  Category Total_Citations 2020_JIF  \
# 157  GASTROENTEROLOGY & HEPATOLOGY - SCIE          28,955     9.43
# 38                        ONCOLOGY - SCIE          40,294     9.16
# 217   MEDICINE, GENERAL & INTERNAL - SCIE          12,653     8.48
# 64            UROLOGY & NEPHROLOGY - SCIE          21,638     8.24
# 65            UROLOGY & NEPHROLOGY - SCIE          21,638     8.24
# ..                                    ...             ...      ...
# 48    MEDICINE, GENERAL & INTERNAL - SCIE            3266     0.82
# 89                         SURGERY - SCIE           6,964     0.69
# 214   MEDICINE, GENERAL & INTERNAL - SCIE            5078     0.68
# 160   MEDICINE, GENERAL & INTERNAL - SCIE             164     0.63
# 114    PERIPHERAL VASCULAR DISEASE - ESCI           3,160      NaN
#
#     JIF_Quartile  2020 _JCI Percentage_of_OA_Gold
# 157           Q1       1.59                 2.45%
# 38            Q1       1.63                21.52%
# 217           Q1       2.65               100.00%
# 64            Q1       2.37                 0.63%
# 65            Q1       2.37                 0.63%
# ..           ...        ...                   ...
# 48           3.8       6.80                  2686
# 89            Q4       0.24                 0.22%
# 214          3.8       7.00                  3453
# 160            6       5.30                   104
# 114          NaN       0.61               100.00%
#
# [225 rows x 18 columns]

# %%
# check didn't matched
IsNotIN=I_Papers[I_Papers.EndNote_ID.isin(set(I_Papers.EndNote_ID)-set(mapped.EndNote_ID))]
IsNotIN
# Out:
#       EndNote_ID                                       Article_Name  \
# 421          422  Evaluation of the quality of antenatal care us...
# 900          901  Prediction of mortality in patients undergoing...
# 927          928  Primary Nonadherence, Associated Clinical Outc...
# 1128        1129  Identifying Risk of Future Asthma Attacks Usin...
# 1229        1230  Risk of moderate to advanced kidney disease in...
# 1665        1666  Effect of cardiac rehabilitation referral stra...
# 1821        1822  The use of a standardized order set reduces sy...
# 1900        1901  Clinical utility of the revised cardiac risk i...
# 2392        2393  Impact of deprivation, ethnicity, and insulin ...
# 3042        3043  Rate of bone density change does not enhance f...
# 3046        3047  Does Alternative and Traditional WASAM (Local ...
# 3092        3093  Trends in Pediatric Emergency Department Utili...
# 3431        3432  Incidence and predictors of surgical site infe...
# 3696        3697  Association between second-generation antipsyc...
# 3706        3707  Associations Between Pediatric Palliative Care...
# 3882        3883  Antibiotic prescription in emergency dental se...
# 4051        4052  Pressure ulcer risk assessment: retrospective ...
# 4064        4065  Gestational weight gain among minority adolesc...
# 4361        4362  Changes in alcohol use associated with changes...
# 4426        4427  Childhood Physical and Sexual Abuse Predicts S...
# 4691        4692  Mortality and Stroke Recurrence in a Rehabilit...
# 4728        4729  Who Gives Birth in the Water? A Retrospective ...
# 4834        4835  Effect of Clinical Variables on the Volume of ...
# 4872        4873  Comparison of analgaesia with lumbar epidurals...
# 4916        4917  Likelihood of acute coronary syndrome in emerg...
# 4959        4960  Liver function changes after transarterial che...
# 5218        5219  Patterns of drug use and abuse among aging adu...
# 5299        5300  General Anaesthesia Protocols for Patients Und...
# 5496        5497  Effect of Registered Dietitian Nutritionist Or...
# 5499        5500  Comparison of the consumption of antidepressan...
# 5504        5505  Epidemiology and correlates of osteoporotic fr...
# 5550        5551  Image-guided cryoablation for the treatment of...
# 5604        5605  Association between health literacy and medica...
# 5739        5740  New recommendation and coverage of low-dose co...
#
#                                                Abstract  Year  \
# 421   BACKGROUND: Evaluation of the quality of anten...  2014
# 900   BACKGROUND/AIMS: Many patients with end-stage ...  2011
# 927   BACKGROUND: Adherence to biologic disease-modi...  2016
# 1128  BACKGROUND: Asthma attacks are common, serious...  2017
# 1229  OBJECTIVE: To determine the risk of chronic ki...  2013
# 1665  BACKGROUND: Although cardiac rehabilitation (C...  2011
# 1821  BACKGROUND: Systemic corticosteroids (SC) are ...  2018
# 1900  OBJECTIVES: The revised Cardiac Risk Index (RC...  2018
# 2392  BACKGROUND: There is marked variation in diabe...  2017
# 3042  CONTEXT: There is contradictory information on...  2012
# 3046  INTRODUCTION: A large heterogeneous group of u...  2016
# 3092  OBJECTIVE: To examine the effect of state yout...  2018
# 3431  BACKGROUND: Occurrence of calcaneus fractures ...  2018
# 3696  PURPOSE: To assess the association of second-g...  2013
# 3706  OBJECTIVES: Our aim in this study was to under...  2018
# 3882  OBJECTIVES: To analyse prescription of antibod...  2019
# 4051  AIMS AND OBJECTIVES: To analyse the Braden Sca...  2015
# 4064  BACKGROUND: In adolescents, there is limited e...  2018
# 4361  BACKGROUND: Among groups of persons living wit...  2018
# 4426  OBJECTIVE: To examine whether childhood physic...  2018
# 4691  BACKGROUND: Chagas disease is related to ische...  2018
# 4728  INTRODUCTION: Most waterbirth studies have bee...  2019
# 4834  OBJECTIVE To identify clinical variables that ...  2017
# 4872  PURPOSE: Significant post-operative pain occur...  2017
# 4916  BACKGROUND: There is a circadian and circasept...  2012
# 4959  BACKGROUND: The real-world incidence of chroni...  2019
# 5218  This study characterized the extent and patter...  2010
# 5299  OBJECTIVES: This study aimed to review general...  2017
# 5496  BACKGROUND: Adequate nutrition is linked to im...  2019
# 5499  BACKGROUND: Health professionals and organizat...  2010
# 5504  This study analyzed data on 87,224 osteoporoti...  2018
# 5550  PURPOSE: The role of image-guided thermal abla...  2014
# 5604  BACKGROUND: Low health literacy is associated ...  2015
# 5739  BACKGROUND: In 2013, the US Preventive Service...  2018
#
#                                                 Journal  PubMed_ID Language  \
# 421                        BMC PREGNANCY AND CHILDBIRTH   24885103      eng
# 900                          NEPHRON: CLINICAL PRACTICE   21071962      eng
# 927                             J MANAG CARE SPEC PHARM   27003550      eng
# 1128                       J ALLERGY CLIN IMMUNOL PRACT   28017629      eng
# 1229                                                BMJ   24129480      eng
# 1665                      ARCHIVES OF INTERNAL MEDICINE   21325114      eng
# 1821  INTERNATIONAL JOURNAL OF CHRONIC OBSTRUCTIVE P...   30100717      eng
# 1900                    CLINICAL INTERVENTIONS IN AGING   29317808      eng
# 2392                                 PEDIATRIC DIABETES   27534520      eng
# 3042   JOURNAL OF CLINICAL ENDOCRINOLOGY AND METABOLISM   22278427      eng
# 3046                           GULF JOURNAL OF ONCOLOGY   28191804      eng
# 3092              JOURNAL OF HEAD TRAUMA REHABILITATION   30395043      eng
# 3431        JOURNAL OF ORTHOPAEDIC SURGERY AND RESEARCH   30458814      eng
# 3696                       JOURNAL OF ADOLESCENT HEALTH   23427784      eng
# 3706                                       HOSP PEDIATR   29436391      eng
# 3882                       INTERNATIONAL DENTAL JOURNAL   30600530      eng
# 4051                        JOURNAL OF CLINICAL NURSING   26316350      eng
# 4064                        WORLD JOURNAL OF PEDIATRICS   29516393      eng
# 4361                        DRUG AND ALCOHOL DEPENDENCE   29859388      eng
# 4426            PRIMARY CARE COMPANION TO CNS DISORDERS   30152644      eng
# 4691                                 EUROPEAN NEUROLOGY   29539612      eng
# 4728                          J MIDWIFERY WOMENS HEALTH   30968545      eng
# 4834        INFECTION CONTROL AND HOSPITAL EPIDEMIOLOGY   29157318      eng
# 4872                         INTERNATIONAL ORTHOPAEDICS   28396932      eng
# 4916                                 BMC RESEARCH NOTES   22871081      eng
# 4959                                         BMC CANCER   31409405      eng
# 5218                        DRUG AND ALCOHOL DEPENDENCE   20395074      eng
# 5299           SULTAN QABOOS UNIVERSITY MEDICAL JOURNAL   28417028      eng
# 5496                     NUTRITION IN CLINICAL PRACTICE   30741444      eng
# 5499                                  BMC PUBLIC HEALTH   20478063      eng
# 5504                                    ARCH OSTEOPOROS   29502187      eng
# 5550                                 SKELETAL RADIOLOGY   24972918      eng
# 5604                       BMC HEALTH SERVICES RESEARCH   26113118      eng
# 5739                       BMC HEALTH SERVICES RESEARCH   29976189      eng
#
#                                     DOI       ISSN
# 421            10.1186/1471-2393-14-168  1471-2393
# 900                   10.1159/000321525  1660-2110
# 927         10.18553/jmcp.2016.22.3.209
# 1128         10.1016/j.jaip.2016.11.007
# 1229                  10.1136/bmj.f5961  0959-8138
# 1665     10.1001/archinternmed.2010.501  0003-9926
# 1821               10.2147/copd.S165665  1176-9106
# 1900                10.2147/cia.S144832  1176-9092
# 2392                 10.1111/pedi.12407  1399-543x
# 3042               10.1210/jc.2011-2871  0021-972x
# 3046                                     2078-2101
# 3092       10.1097/htr.0000000000000397  0885-9701
# 3431          10.1186/s13018-018-1003-y  1749-799x
# 3696   10.1016/j.jadohealth.2012.10.272  1054-139x
# 3706            10.1542/hpeds.2017-0016  2154-1663
# 3882                  10.1111/idj.12460  0020-6539
# 4051                 10.1111/jocn.12927  0962-1067
# 4064          10.1007/s12519-018-0143-9
# 4361   10.1016/j.drugalcdep.2018.04.022  0376-8716
# 4426               10.4088/PCC.18m02317  2155-7780
# 4691                  10.1159/000488033  0014-3022
# 4728                 10.1111/jmwh.12961  1526-9523
# 4834               10.1017/ice.2017.230  0899-823x
# 4872          10.1007/s00264-017-3465-7  0341-2695
# 4916            10.1186/1756-0500-5-420  1756-0500
# 4959          10.1186/s12885-019-5989-2  1471-2407
# 5218   10.1016/j.drugalcdep.2010.02.020  0376-8716
# 5299      10.18295/squmj.2016.17.01.009  2075-051X
# 5496                  10.1002/ncp.10259  0884-5336
# 5499           10.1186/1471-2458-10-255  1471-2458
# 5504          10.1007/s11657-018-0432-x
# 5550          10.1007/s00256-014-1939-x  0364-2348
# 5604          10.1186/s12913-015-0887-z  1472-6963
# 5739          10.1186/s12913-018-3338-9  1472-6963

# %%
testMergedResults=Match_Impact[Match_Impact.EndNote_ID.isin(IsNotIN.EndNote_ID)]
testMergedResults.Journal
# Out:
# 0                           BMC PREGNANCY AND CHILDBIRTH
# 12                            NEPHRON: CLINICAL PRACTICE
# 16                               J MANAG CARE SPEC PHARM
# 18                          J ALLERGY CLIN IMMUNOL PRACT
# 20                                                   BMJ
# 36                         ARCHIVES OF INTERNAL MEDICINE
# 43     INTERNATIONAL JOURNAL OF CHRONIC OBSTRUCTIVE P...
# 46                       CLINICAL INTERVENTIONS IN AGING
# 66                                    PEDIATRIC DIABETES
# 102     JOURNAL OF CLINICAL ENDOCRINOLOGY AND METABOLISM
# 103                             GULF JOURNAL OF ONCOLOGY
# 107                JOURNAL OF HEAD TRAUMA REHABILITATION
# 129          JOURNAL OF ORTHOPAEDIC SURGERY AND RESEARCH
# 147                         JOURNAL OF ADOLESCENT HEALTH
# 148                                         HOSP PEDIATR
# 154                         INTERNATIONAL DENTAL JOURNAL
# 158                          JOURNAL OF CLINICAL NURSING
# 159                          WORLD JOURNAL OF PEDIATRICS
# 175                          DRUG AND ALCOHOL DEPENDENCE
# 182              PRIMARY CARE COMPANION TO CNS DISORDERS
# 193                                   EUROPEAN NEUROLOGY
# 194                            J MIDWIFERY WOMENS HEALTH
# 199          INFECTION CONTROL AND HOSPITAL EPIDEMIOLOGY
# 201                           INTERNATIONAL ORTHOPAEDICS
# 206                                   BMC RESEARCH NOTES
# 211                                           BMC CANCER
# 221                          DRUG AND ALCOHOL DEPENDENCE
# 230             SULTAN QABOOS UNIVERSITY MEDICAL JOURNAL
# 237                       NUTRITION IN CLINICAL PRACTICE
# 238                                    BMC PUBLIC HEALTH
# 239                                      ARCH OSTEOPOROS
# 243                                   SKELETAL RADIOLOGY
# 246                         BMC HEALTH SERVICES RESEARCH
# 249                         BMC HEALTH SERVICES RESEARCH
# Name: Journal, dtype: object

# %%
#test MERICAN JOURNAL OF ALZHEIMERS DISEASE AND OTHER DEMENTIAS 
Journal_impact[Journal_impact.Journal_name=="AMERICAN JOURNAL OF ALZHEIMERS DISEASE AND OTHER DEMENTIAS"]
I_Journal[I_Journal.Journal_name=="AMERICAN JOURNAL OF ALZHEIMER'S DISEASE AND OTHER DEMENTIAS"]
# Out:
#                                           Journal_name  paper_count
# 134  AMERICAN JOURNAL OF ALZHEIMER'S DISEASE AND OT...            1

# %%
Journal_impact[Journal_impact.Journal_name=="ARTHRITIS & RHEUMATOLOGY"]
# Out:
#       ï»¿_ID              Journal_name       ISSN      eISSN  \
# 2378    2379  ARTHRITIS & RHEUMATOLOGY  2326-5191  2326-5205
#
#                  Category Total_Citations 2020_JIF JIF_Quartile  2020 _JCI  \
# 2378  RHEUMATOLOGY - SCIE          16,730    11.00           Q1       2.71
#
#      Percentage_of_OA_Gold
# 2378                21.67%

# %%
I_Journal[I_Journal.Journal_name=="ARTHRITIS RHEUMATOL"]
# Out:
#            Journal_name  paper_count
# 72  ARTHRITIS RHEUMATOL            1

# %%
Not_In_I_Journal=set(I_Papers.ISSN)-set(match_ISSN)
print(len(Not_In_I_Journal))
test=I_Papers[I_Papers.ISSN.isin(Not_In_I_Journal)]
test
# Out:
# 143
#       EndNote_ID                                       Article_Name  \
# 421          422  Evaluation of the quality of antenatal care us...
# 689          690  The effectiveness of varenicline versus nicoti...
# 690          691  Development and validation of an ICD-10-based ...
# 699          700  Cost Savings from Reducing Pain Through the De...
# 729          730  The clinical epidemiology of fatigue in newly ...
# ...          ...                                                ...
# 5782        5783  Association Between Positive Cultures During A...
# 5789        5790  Zolpidem is independently associated with incr...
# 5791        5792  Racial/ethnic differences in the prevalence of...
# 5804        5805  Synchronization of administrations of chemothe...
# 5832        5833  Comparative Effectiveness and Resource Usage i...
#
#                                                Abstract  Year  \
# 421   BACKGROUND: Evaluation of the quality of anten...  2014
# 689   BACKGROUND: There is limited evidence about th...  2017
# 690   BACKGROUND: There was no established disabilit...  2018
# 699   OBJECTIVES: An important task facing hospitals...  2018
# 729   BACKGROUND: Fatigue is a common and distressin...  2017
# ...                                                 ...   ...
# 5782  The number of patients with cancer being admit...  2018
# 5789  BACKGROUND: Inpatient falls are associated wit...  2013
# 5791  OBJECTIVE: To examine racial/ethnic difference...  2013
# 5804  PURPOSE: The erythropoiesis-stimulating agents...  2013
# 5832  BACKGROUND: Weekly (qw) nanoparticle albumin-b...  2017
#
#                                                 Journal  PubMed_ID Language  \
# 421                        BMC PREGNANCY AND CHILDBIRTH   24885103      eng
# 689               INTERNATIONAL JOURNAL OF EPIDEMIOLOGY   29040555      eng
# 690                                              INJURY   29352592      eng
# 699   JOURNAL OF ALTERNATIVE AND COMPLEMENTARY MEDICINE   29474095      eng
# 729                        BMC CARDIOVASCULAR DISORDERS   28490326      eng
# ...                                                 ...        ...      ...
# 5782                                     CANCER CONTROL   30086666      eng
# 5789                       JOURNAL OF HOSPITAL MEDICINE   23165956      eng
# 5791                                      DIABETES CARE   23238659      eng
# 5804                          SUPPORTIVE CARE IN CANCER   23756616      eng
# 5832                               CLINICAL LUNG CANCER   28117221      eng
#
#                                 DOI       ISSN
# 421        10.1186/1471-2393-14-168  1471-2393
# 689              10.1093/ije/dyx109  0300-5771
# 690    10.1016/j.injury.2017.12.021  0020-1383
# 699           10.1089/acm.2017.0203  1075-5535
# 729       10.1186/s12872-017-0555-9  1471-2261
# ...                             ...        ...
# 5782       10.1177/1073274818794162  1073-2748
# 5789               10.1002/jhm.1985  1553-5592
# 5791              10.2337/dc12-0951  0149-5992
# 5804      10.1007/s00520-013-1830-7  0941-4355
# 5832     10.1016/j.cllc.2016.12.008  1525-7304
#
# [175 rows x 9 columns]

# %%
# change all name into upper case 
for i in range(len(I_Journal.Journal_name)):
    I_Journal.Journal_name[i]=I_Journal.Journal_name[i].upper()
print(I_Journal)
# Out:
#                          Journal_name  paper_count
# 0                            BMJ OPEN            5
# 1                            PLOS ONE            4
# 2    ANNALS OF THE RHEUMATIC DISEASES            3
# 3               MATERN CHILD HEALTH J            2
# 4                  WORLD NEUROSURGERY            2
# ..                                ...          ...
# 140                           SURGERY            1
# 141                      SCAND J UROL            1
# 142                PEDIATRIC DIABETES            1
# 143        PREVENTING CHRONIC DISEASE            1
# 144              CLINICAL LUNG CANCER            1
#
# [145 rows x 2 columns]
# /var/folders/v0/r16j2f9545n7rrq_rvqlxn180000gn/T/ipykernel_10893/3504582545.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   I_Journal.Journal_name[i]=I_Journal.Journal_name[i].upper()

# %% [markdown]
# ## Step 6 Analyze Numerator

# %%
# Read Method_Review data
#Method_Review=pd.read_excel('/Users/chenyuli/Research_Thesis/Validate/20210707/20210707_method_review.xlsx')
Method_Review=pd.read_csv('/Users/chenyuli/Research_Thesis/Validate/20210707/20210707_method_review.csv')
#AR_Include=Method_Review[Method_Review.Include_in_Research=='Yes']
Method_Review=Method_Review[Method_Review.EndNote_ID.isin(AR_Include.EndNote_Index)]

# %%
Method_Review
# Out:
#      EndNote_ID   Pubmed_ID              Analytic_Method_Name  \
# 0        1230.0  24129480.0    Cox proportional hazard models
# 1        1230.0  24129480.0              Sensitivity analysis
# 2        1564.0  21694510.0              Sensitivity analysis
# 3        1564.0  21694510.0                 Statistic testing
# 4        1564.0  21694510.0  Multivariate Logistic Regression
# ..          ...         ...                               ...
# 407      4342.0  21801091.0               Logistic Regression
# 408      4342.0  21801091.0               kaplan-Meier method
# 409      4342.0  21801091.0                 statistic Testing
# 410      5790.0  23165956.0               Logistic Regression
# 411      5790.0  23165956.0            descriptive statistics
#
#      Real_World_Evidence  Unnamed: 4 Year Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0                      0      2013.0  NaN        NaN         NaN         NaN
# 1    Real-World Evidence      2013.0  NaN        NaN         NaN         NaN
# 2    Real-World Evidence      2011.0  NaN        NaN         NaN         NaN
# 3                      0      2011.0  NaN        NaN         NaN         NaN
# 4                      0      2011.0  NaN        NaN         NaN         NaN
# ..                   ...         ...  ...        ...         ...         ...
# 407                    0      2011.0  NaN        NaN         NaN         NaN
# 408                    0      2011.0  NaN        NaN         NaN         NaN
# 409                    0      2011.0  NaN        NaN         NaN         NaN
# 410                    0      2013.0  NaN        NaN         NaN         NaN
# 411                    0      2013.0  NaN        NaN         NaN         NaN
#
#      Unnamed: 9
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 407         NaN
# 408         NaN
# 409         NaN
# 410         NaN
# 411         NaN
#
# [398 rows x 10 columns]

# %%
Real_World_Method_list=Method_Review[Method_Review.Real_World_Evidence!='0'].EndNote_ID.unique()
len(Real_World_Method_list)
# Out:
# 50

# %%
RW_Methods_Papers=articles[articles['EndNote_ID'].isin(Real_World_Method_list)]
RW_Methods_Papers
# Out:
#       EndNote_ID                                       Article_Name  \
# 689          690  The effectiveness of varenicline versus nicoti...
# 774          775  Assessment of the relationship between diabete...
# 803          804  Type and timing of heralding in ST-elevation a...
# 956          957  Statin use and the risk of colorectal cancer i...
# 1219        1220  Low-dose aspirin and risk of upper/lower gastr...
# 1229        1230  Risk of moderate to advanced kidney disease in...
# 1278        1279  Angiotensin receptor blockers: are they relate...
# 1457        1458  Does Angiotensin-Converting Enzyme Inhibitor a...
# 1505        1506  Recurrent antibiotic exposure may promote canc...
# 1563        1564  Derivation and diagnostic accuracy of the surg...
# 1811        1812  Effectiveness, safety and costs of thromboembo...
# 1904        1905  Assessing bleeding risk in 4824 Asian patients...
# 2197        2198  Tacrolimus Trough Concentration Variability an...
# 2633        2634  Does Prehospital Time Influence Clinical Outco...
# 2757        2758  The effect of anatomic location of injury on m...
# 2801        2802  Assessment of the Risk of Fractures Because of...
# 3016        3017  Insurance status is a predictor of failure to ...
# 3114        3115  Elevated Triglycerides (‚â•150 mg/dL) and High...
# 3167        3168  Obesity in Older People With and Without Condi...
# 3196        3197  Trends in the incidence of testing for vitamin...
# 3368        3369  Factors Associated with Chronic Kidney Disease...
# 3412        3413  Hyperuricemia is associated with increased hos...
# 3427        3428  Non-neurological outcomes after complete traum...
# 3437        3438  Rising mortality in patients with combined bur...
# 3496        3497  Incidence and risk factors for infection in sp...
# 3530        3531  The unclosing premature mortality gap in gout:...
# 3590        3591  Diagnostic intervals and its association with ...
# 3761        3762  Comparative Effectiveness of Initial Treatment...
# 3875        3876  Effect of psoriasis severity on hypertension c...
# 3904        3905  Association Between Thyroid Disease and Uveiti...
# 4289        4290  Neonatal Outcomes Associated With Placental Ab...
# 4491        4492  Decreasing outpatient cardiac catheterization ...
# 4521        4522  Relationship between age and erectile dysfunct...
# 4527        4528  Effect of bisphosphonates on knee replacement ...
# 4761        4762  Fracture risk in type 2 diabetic patients: A c...
# 4820        4821  Association of worksite wellness center attend...
# 4904        4905  Methylprednisolone Therapy in Acute Traumatic ...
# 4911        4912  Temporal Trends of Venous Thromboembolism Risk...
# 4925        4926  Persistent sex disparities in implantable card...
# 4959        4960  Liver function changes after transarterial che...
# 4965        4966  Impact of antibiotic treatment duration on out...
# 4988        4989  Proton Pump Inhibitors Do Not Increase Risk fo...
# 5067        5068  Association of Neighborhood Socioeconomic Cont...
# 5245        5246  Neonatal health of infants born to mothers wit...
# 5284        5285  Evolving landscape of stroke prevention in atr...
# 5566        5567  Comparison of intraoperative basal fluid requi...
# 5625        5626  Comparative Toxicity and Effectiveness of Tras...
# 5660        5661  Hospital Utilization Among Rural Children Serv...
# 5740        5741  Association between red blood cell storage dur...
# 5804        5805  Synchronization of administrations of chemothe...
#
#                                                Abstract  Year  \
# 689   BACKGROUND: There is limited evidence about th...  2017
# 774   AIMS: Assess the relationship between timely t...  2018
# 803   AIMS: It is widely thought that ST-elevation m...  2013
# 956   There is extensive debate regarding the protec...  2019
# 1219  Introduction: Risks of low-dose aspirin-associ...  2019
# 1229  OBJECTIVE: To determine the risk of chronic ki...  2013
# 1278  INTRODUCTION: Angiotensin receptor blockers (A...  2013
# 1457  STUDY OBJECTIVE: It has been suggested that us...  2016
# 1505  BACKGROUND: Bacterial dysbiosis was previously...  2015
# 1563  BACKGROUND: Acute lung injury (ALI) is a serio...  2011
# 1811  PURPOSE: Atrial fibrillation is the most commo...  2016
# 1904  The risks of major bleeding and intracranial h...  2016
# 2197  BACKGROUND: Low tacrolimus concentrations have...  2017
# 2633  OBJECTIVE: Prehospital time potentially impact...  2017
# 2757  INTRODUCTION: Injury is a significant cause of...  2017
# 2801  INTRODUCTION: Submariners are known to have de...  2015
# 3016  BACKGROUND: Disparities in outcomes for uninsu...  2013
# 3114  PURPOSE: Real-world data may provide insight i...  2019
# 3167  BACKGROUND: Moderate obesity in later life may...  2017
# 3196  OBJECTIVE: To investigate trends in the incide...  2019
# 3368  BACKGROUND: Chronic kidney disease (CKD) is a ...  2018
# 3412  BACKGROUND AND AIM: Chronic hyperuricemia is r...  2016
# 3427  It remains unclear whether the benefits of ear...  2013
# 3437  Combined trauma in the burn patient has been p...  2018
# 3496  BACKGROUND: Surgical site infection (SSI) is a...  2018
# 3530  OBJECTIVE: Gout, the most common inflammatory ...  2017
# 3590  Rapid diagnostic pathways for cancer have been...  2015
# 3761  BACKGROUND: Head injury is an increasing contr...  2018
# 3875  IMPORTANCE: Hypertension is prevalent among pa...  2015
# 3904  IMPORTANCE: Common pathophysiological mechanis...  2017
# 4289  Placental abruption (early separation of the p...  2017
# 4491  Cardiac computed tomographic angiography (CTA)...  2010
# 4521  AIMS: With self-reporting of erectile dysfunct...  2016
# 4527  PURPOSE: Bone remodelling as a therapeutic tar...  2018
# 4761  BACKGROUND: An increased fracture risk has bee...  2018
# 4820  OBJECTIVE: To assess the impact of wellness ce...  2015
# 4904  BACKGROUND: The objective of this study was to...  2017
# 4911  OBJECTIVE: Giant cell arteritis (GCA) and the ...  2017
# 4925  BACKGROUND: Clinical guidelines recommend card...  2018
# 4959  BACKGROUND: The real-world incidence of chroni...  2019
# 4965  PURPOSE: Clinical guidelines recommend at leas...  2019
# 4988  OBJECTIVES: Patients in the intensive care uni...  2016
# 5067  BACKGROUND: Cardiac rehabilitation (CR) is und...  2017
# 5245  BACKGROUND: Maternal asthma is associated with...  2014
# 5284  OBJECTIVE: To describe the changes in prescrib...  2017
# 5566  There has been recent progress in intraoperati...  2017
# 5625  Purpose The combination of chemotherapy and tr...  2017
# 5660  IMPORTANCE: Telemedicine is increasingly used ...  2019
# 5740  BACKGROUND: Prolonged storage of red blood cel...  2014
# 5804  PURPOSE: The erythropoiesis-stimulating agents...  2013
#
#                                                 Journal  PubMed_ID Language  \
# 689               INTERNATIONAL JOURNAL OF EPIDEMIOLOGY   29040555      eng
# 774                                            PLOS ONE   29894495      eng
# 803                   EUR HEART J ACUTE CARDIOVASC CARE   24222835      eng
# 956                                  SCIENTIFIC REPORTS   31537841      eng
# 1219                                 ANNALS OF MEDICINE   31025592      eng
# 1229                                                BMJ   24129480      eng
# 1278                            JOURNAL OF HYPERTENSION   23822929      eng
# 1457                                    PHARMACOTHERAPY   26846893      eng
# 1505                         EUROPEAN JOURNAL OF CANCER   26338196      eng
# 1563                                     ANESTHESIOLOGY   21694510      eng
# 1811                                           BMJ OPEN   26823179      eng
# 1904                                 SCIENTIFIC REPORTS   27557876      eng
# 2197                                    TRANSPLANTATION   28658199      eng
# 2633                         PREHOSPITAL EMERGENCY CARE   28489503      eng
# 2757                                             INJURY   28551054      eng
# 2801                                  MILITARY MEDICINE   26126249      eng
# 3016                           J TRAUMA ACUTE CARE SURG   24064890      eng
# 3114                             VASC HEALTH RISK MANAG   31824165      eng
# 3167  JOURNALS OF GERONTOLOGY SERIES A: BIOLOGICAL S...   27492450      eng
# 3196                                           BMJ OPEN   31167871      eng
# 3368                                            NEPHRON   29253844      eng
# 3412  NUTRITION, METABOLISM, AND CARDIOVASCULAR DISE...   27555289      eng
# 3427                             JOURNAL OF NEUROTRAUMA   23829420      eng
# 3437                                              BURNS   30075972      eng
# 3496              AMERICAN JOURNAL OF INFECTION CONTROL   29129272      eng
# 3530                   ANNALS OF THE RHEUMATIC DISEASES   28122760      eng
# 3590                                           PLOS ONE   25933397      eng
# 3761        JOURNAL OF THE AMERICAN COLLEGE OF SURGEONS   29501610      eng
# 3875                                      JAMA DERMATOL   25322196      eng
# 3904                                    JAMA OPHTHALMOL   28472213      eng
# 4289                   AMERICAN JOURNAL OF EPIDEMIOLOGY   28595292      eng
# 4491                                  MILITARY MEDICINE   20684459      eng
# 4521         INTERNATIONAL JOURNAL OF CLINICAL PRACTICE   28032424      eng
# 4527                   ANNALS OF THE RHEUMATIC DISEASES   28988204      eng
# 4761                                           PLOS ONE   30192850      eng
# 4820  JOURNAL OF OCCUPATIONAL AND ENVIRONMENTAL MEDI...   25742528      eng
# 4904                           ANESTHESIA AND ANALGESIA   28319547      eng
# 4911                                ARTHRITIS RHEUMATOL   28029234      eng
# 4925              PACING AND CLINICAL ELECTROPHYSIOLOGY   29959781      eng
# 4959                                         BMC CANCER   31409405      eng
# 4965               PHARMACOEPIDEMIOLOGY AND DRUG SAFETY   31050078      eng
# 4988               AMERICAN JOURNAL OF GASTROENTEROLOGY   27575714      eng
# 5067                                   J AM HEART ASSOC   29021267      eng
# 5245         JOURNAL OF ALLERGY AND CLINICAL IMMUNOLOGY   23916153      eng
# 5284                                           BMJ OPEN   28951401      eng
# 5566                               MEDICINE (BALTIMORE)   29381975      eng
# 5625                       JOURNAL OF CLINICAL ONCOLOGY   28727517      eng
# 5660                                     JAMA NETW OPEN   31418803      eng
# 5740                                 BMC ANESTHESIOLOGY   25352766      eng
# 5804                          SUPPORTIVE CARE IN CANCER   23756616      eng
#
#                                      DOI       ISSN
# 689                   10.1093/ije/dyx109  0300-5771
# 774         10.1371/journal.pone.0199011  1932-6203
# 803             10.1177/2048872613487495  2048-8726
# 956           10.1038/s41598-019-49877-5  2045-2322
# 1219       10.1080/07853890.2019.1591635  0785-3890
# 1229                   10.1136/bmj.f5961  0959-8138
# 1278        10.1097/HJH.0b013e3283621ea3  0263-6352
# 1457                   10.1002/phar.1704  0277-0008
# 1505          10.1016/j.ejca.2015.08.015  0959-8049
# 1563        10.1097/ALN.0b013e31821b5839  0003-3022
# 1811         10.1136/bmjopen-2015-010144  2044-6055
# 1904                   10.1038/srep31755  2045-2322
# 2197         10.1097/tp.0000000000001840  0041-1337
# 2633       10.1080/10903127.2017.1294223  1090-3127
# 2757        10.1016/j.injury.2017.05.023  0020-1383
# 2801           10.7205/milmed-d-14-00489  0026-4075
# 3016         10.1097/TA.0b013e3182a53aaa  2163-0755
# 3114                10.2147/vhrm.S221289  1176-6344
# 3167               10.1093/gerona/glw147  1079-5006
# 3196         10.1136/bmjopen-2018-028355  2044-6055
# 3368                   10.1159/000485110  1660-8151
# 3412        10.1016/j.numecd.2016.06.008  0939-4753
# 3427               10.1089/neu.2013.2957  0897-7151
# 3437         10.1016/j.burns.2018.07.003  0305-4179
# 3496          10.1016/j.ajic.2017.09.025  0196-6553
# 3530     10.1136/annrheumdis-2016-210588  0003-4967
# 3590        10.1371/journal.pone.0126608  1932-6203
# 3761   10.1016/j.jamcollsurg.2018.01.055  1072-7515
# 3875      10.1001/jamadermatol.2014.2094  2168-6068
# 3904    10.1001/jamaophthalmol.2017.1009  2168-6165
# 4289                  10.1093/aje/kwx202  0002-9262
# 4491           10.7205/milmed-d-09-00163  0026-4075
# 4521                  10.1111/ijcp.12908  1368-5031
# 4527     10.1136/annrheumdis-2017-211811  0003-4967
# 4761        10.1371/journal.pone.0203533  1932-6203
# 4820        10.1097/jom.0000000000000392  1076-2752
# 4904        10.1213/ane.0000000000001906  0003-2999
# 4911                   10.1002/art.39847  2326-5191
# 4925                  10.1111/pace.13435  0147-8389
# 4959           10.1186/s12885-019-5989-2  1471-2407
# 4965                    10.1002/pds.4791  1053-8569
# 4988                10.1038/ajg.2016.343  0002-9270
# 5067             10.1161/jaha.117.006260  2047-9980
# 5245          10.1016/j.jaci.2013.06.012  0091-6749
# 5284         10.1136/bmjopen-2016-015363  2044-6055
# 5566         10.1097/md.0000000000008763  0025-7974
# 5625            10.1200/jco.2016.71.4345  0732-183X
# 5660   10.1001/jamanetworkopen.2019.9364  2574-3805
# 5740             10.1186/1471-2253-14-95  1471-2253
# 5804           10.1007/s00520-013-1830-7  0941-4355

# %%
Sensitivity_list=Method_Review[Method_Review.Analytic_Method_Name=='Sensitivity analysis'].EndNote_ID.unique()
print(len(Sensitivity_list))
Sensitivity_Papers=articles[articles['EndNote_ID'].isin(Sensitivity_list)]
Sensitivity_Papers
# Out:
# 31
#       EndNote_ID                                       Article_Name  \
# 689          690  The effectiveness of varenicline versus nicoti...
# 774          775  Assessment of the relationship between diabete...
# 803          804  Type and timing of heralding in ST-elevation a...
# 1229        1230  Risk of moderate to advanced kidney disease in...
# 1457        1458  Does Angiotensin-Converting Enzyme Inhibitor a...
# 1505        1506  Recurrent antibiotic exposure may promote canc...
# 1563        1564  Derivation and diagnostic accuracy of the surg...
# 1811        1812  Effectiveness, safety and costs of thromboembo...
# 1904        1905  Assessing bleeding risk in 4824 Asian patients...
# 2197        2198  Tacrolimus Trough Concentration Variability an...
# 2757        2758  The effect of anatomic location of injury on m...
# 3016        3017  Insurance status is a predictor of failure to ...
# 3167        3168  Obesity in Older People With and Without Condi...
# 3196        3197  Trends in the incidence of testing for vitamin...
# 3368        3369  Factors Associated with Chronic Kidney Disease...
# 3412        3413  Hyperuricemia is associated with increased hos...
# 3875        3876  Effect of psoriasis severity on hypertension c...
# 3904        3905  Association Between Thyroid Disease and Uveiti...
# 4289        4290  Neonatal Outcomes Associated With Placental Ab...
# 4521        4522  Relationship between age and erectile dysfunct...
# 4527        4528  Effect of bisphosphonates on knee replacement ...
# 4820        4821  Association of worksite wellness center attend...
# 4904        4905  Methylprednisolone Therapy in Acute Traumatic ...
# 4911        4912  Temporal Trends of Venous Thromboembolism Risk...
# 4959        4960  Liver function changes after transarterial che...
# 4965        4966  Impact of antibiotic treatment duration on out...
# 4988        4989  Proton Pump Inhibitors Do Not Increase Risk fo...
# 5067        5068  Association of Neighborhood Socioeconomic Cont...
# 5245        5246  Neonatal health of infants born to mothers wit...
# 5284        5285  Evolving landscape of stroke prevention in atr...
# 5660        5661  Hospital Utilization Among Rural Children Serv...
#
#                                                Abstract  Year  \
# 689   BACKGROUND: There is limited evidence about th...  2017
# 774   AIMS: Assess the relationship between timely t...  2018
# 803   AIMS: It is widely thought that ST-elevation m...  2013
# 1229  OBJECTIVE: To determine the risk of chronic ki...  2013
# 1457  STUDY OBJECTIVE: It has been suggested that us...  2016
# 1505  BACKGROUND: Bacterial dysbiosis was previously...  2015
# 1563  BACKGROUND: Acute lung injury (ALI) is a serio...  2011
# 1811  PURPOSE: Atrial fibrillation is the most commo...  2016
# 1904  The risks of major bleeding and intracranial h...  2016
# 2197  BACKGROUND: Low tacrolimus concentrations have...  2017
# 2757  INTRODUCTION: Injury is a significant cause of...  2017
# 3016  BACKGROUND: Disparities in outcomes for uninsu...  2013
# 3167  BACKGROUND: Moderate obesity in later life may...  2017
# 3196  OBJECTIVE: To investigate trends in the incide...  2019
# 3368  BACKGROUND: Chronic kidney disease (CKD) is a ...  2018
# 3412  BACKGROUND AND AIM: Chronic hyperuricemia is r...  2016
# 3875  IMPORTANCE: Hypertension is prevalent among pa...  2015
# 3904  IMPORTANCE: Common pathophysiological mechanis...  2017
# 4289  Placental abruption (early separation of the p...  2017
# 4521  AIMS: With self-reporting of erectile dysfunct...  2016
# 4527  PURPOSE: Bone remodelling as a therapeutic tar...  2018
# 4820  OBJECTIVE: To assess the impact of wellness ce...  2015
# 4904  BACKGROUND: The objective of this study was to...  2017
# 4911  OBJECTIVE: Giant cell arteritis (GCA) and the ...  2017
# 4959  BACKGROUND: The real-world incidence of chroni...  2019
# 4965  PURPOSE: Clinical guidelines recommend at leas...  2019
# 4988  OBJECTIVES: Patients in the intensive care uni...  2016
# 5067  BACKGROUND: Cardiac rehabilitation (CR) is und...  2017
# 5245  BACKGROUND: Maternal asthma is associated with...  2014
# 5284  OBJECTIVE: To describe the changes in prescrib...  2017
# 5660  IMPORTANCE: Telemedicine is increasingly used ...  2019
#
#                                                 Journal  PubMed_ID Language  \
# 689               INTERNATIONAL JOURNAL OF EPIDEMIOLOGY   29040555      eng
# 774                                            PLOS ONE   29894495      eng
# 803                   EUR HEART J ACUTE CARDIOVASC CARE   24222835      eng
# 1229                                                BMJ   24129480      eng
# 1457                                    PHARMACOTHERAPY   26846893      eng
# 1505                         EUROPEAN JOURNAL OF CANCER   26338196      eng
# 1563                                     ANESTHESIOLOGY   21694510      eng
# 1811                                           BMJ OPEN   26823179      eng
# 1904                                 SCIENTIFIC REPORTS   27557876      eng
# 2197                                    TRANSPLANTATION   28658199      eng
# 2757                                             INJURY   28551054      eng
# 3016                           J TRAUMA ACUTE CARE SURG   24064890      eng
# 3167  JOURNALS OF GERONTOLOGY SERIES A: BIOLOGICAL S...   27492450      eng
# 3196                                           BMJ OPEN   31167871      eng
# 3368                                            NEPHRON   29253844      eng
# 3412  NUTRITION, METABOLISM, AND CARDIOVASCULAR DISE...   27555289      eng
# 3875                                      JAMA DERMATOL   25322196      eng
# 3904                                    JAMA OPHTHALMOL   28472213      eng
# 4289                   AMERICAN JOURNAL OF EPIDEMIOLOGY   28595292      eng
# 4521         INTERNATIONAL JOURNAL OF CLINICAL PRACTICE   28032424      eng
# 4527                   ANNALS OF THE RHEUMATIC DISEASES   28988204      eng
# 4820  JOURNAL OF OCCUPATIONAL AND ENVIRONMENTAL MEDI...   25742528      eng
# 4904                           ANESTHESIA AND ANALGESIA   28319547      eng
# 4911                                ARTHRITIS RHEUMATOL   28029234      eng
# 4959                                         BMC CANCER   31409405      eng
# 4965               PHARMACOEPIDEMIOLOGY AND DRUG SAFETY   31050078      eng
# 4988               AMERICAN JOURNAL OF GASTROENTEROLOGY   27575714      eng
# 5067                                   J AM HEART ASSOC   29021267      eng
# 5245         JOURNAL OF ALLERGY AND CLINICAL IMMUNOLOGY   23916153      eng
# 5284                                           BMJ OPEN   28951401      eng
# 5660                                     JAMA NETW OPEN   31418803      eng
#
#                                      DOI       ISSN
# 689                   10.1093/ije/dyx109  0300-5771
# 774         10.1371/journal.pone.0199011  1932-6203
# 803             10.1177/2048872613487495  2048-8726
# 1229                   10.1136/bmj.f5961  0959-8138
# 1457                   10.1002/phar.1704  0277-0008
# 1505          10.1016/j.ejca.2015.08.015  0959-8049
# 1563        10.1097/ALN.0b013e31821b5839  0003-3022
# 1811         10.1136/bmjopen-2015-010144  2044-6055
# 1904                   10.1038/srep31755  2045-2322
# 2197         10.1097/tp.0000000000001840  0041-1337
# 2757        10.1016/j.injury.2017.05.023  0020-1383
# 3016         10.1097/TA.0b013e3182a53aaa  2163-0755
# 3167               10.1093/gerona/glw147  1079-5006
# 3196         10.1136/bmjopen-2018-028355  2044-6055
# 3368                   10.1159/000485110  1660-8151
# 3412        10.1016/j.numecd.2016.06.008  0939-4753
# 3875      10.1001/jamadermatol.2014.2094  2168-6068
# 3904    10.1001/jamaophthalmol.2017.1009  2168-6165
# 4289                  10.1093/aje/kwx202  0002-9262
# 4521                  10.1111/ijcp.12908  1368-5031
# 4527     10.1136/annrheumdis-2017-211811  0003-4967
# 4820        10.1097/jom.0000000000000392  1076-2752
# 4904        10.1213/ane.0000000000001906  0003-2999
# 4911                   10.1002/art.39847  2326-5191
# 4959           10.1186/s12885-019-5989-2  1471-2407
# 4965                    10.1002/pds.4791  1053-8569
# 4988                10.1038/ajg.2016.343  0002-9270
# 5067             10.1161/jaha.117.006260  2047-9980
# 5245          10.1016/j.jaci.2013.06.012  0091-6749
# 5284         10.1136/bmjopen-2016-015363  2044-6055
# 5660   10.1001/jamanetworkopen.2019.9364  2574-3805

# %%
RWM_Years=RW_Methods_Papers['Year']
RWM_Years_Count=RWM_Years.value_counts().reset_index().rename(columns={'index':'Year','Year':'RWM_count'})
RWM_Years_Count.sort_values('Year')
sns.barplot(RWM_Years_Count.Year,RWM_Years_Count.RWM_count,color='gray')
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Year', ylabel='RWM_count'>

# %%
S_Years=Sensitivity_Papers['Year']
S_Years_Count=S_Years.value_counts().reset_index().rename(columns={'index':'Year','Year':'Sensitivity_Analysis_Count'})
S_Years_Count.sort_values('Year')
sns.barplot(S_Years_Count.Year,S_Years_Count.Sensitivity_Analysis_Count,color='gray')
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Year', ylabel='Sensitivity_Analysis_Count'>

# %%
Join_RWP_I=I_Years_Count+RWM_Years_Count

# %%
I_Years_Count.sort_values('Year')
# Out:
#    index  Year  included_number    epoch hatches   colors
# 0      9  2010                4  epoch 1       /  #08519c
# 1      6  2011                9  epoch 1       /  #08519c
# 2      8  2012                6  epoch 1       /  #08519c
# 3      4  2013               16  epoch 1       /  #08519c
# 4      7  2014                7  epoch 2      //  #3182bd
# 5      5  2015               11  epoch 2      //  #3182bd
# 6      3  2016               17  epoch 2      //  #3182bd
# 7      0  2017               35  epoch 3     ///  #6baed6
# 8      1  2018               35  epoch 4    ////  #bdd7e7
# 9      2  2019               35  epoch 5   /////  #eff3ff

# %%
Join_RWM_I=pd.concat([I_Years_Count,RWM_Years_Count],ignore_index=True,sort=True)

# %%
Join_RWM_I= pd.merge(I_Years_Count,RWM_Years_Count,on='Year',how='left').fillna(0)
Join_RWM_I
# Out:
#    index  Year  included_number    epoch hatches   colors  RWM_count
# 0      9  2010                4  epoch 1       /  #08519c        1.0
# 1      6  2011                9  epoch 1       /  #08519c        1.0
# 2      8  2012                6  epoch 1       /  #08519c        0.0
# 3      4  2013               16  epoch 1       /  #08519c        6.0
# 4      7  2014                7  epoch 2      //  #3182bd        2.0
# 5      5  2015               11  epoch 2      //  #3182bd        5.0
# 6      3  2016               17  epoch 2      //  #3182bd        6.0
# 7      0  2017               35  epoch 3     ///  #6baed6       14.0
# 8      1  2018               35  epoch 4    ////  #bdd7e7        8.0
# 9      2  2019               35  epoch 5   /////  #eff3ff        7.0

# %%
#Missing data analysis 
HM_list=Article_Review[(Article_Review.Include_in_Research=='Yes')&(Article_Review.Assessed_Missing_Data!="No")].EndNote_Index
print(len(HM_list))
# Out:
# 39

# %%
### Papers used any of three phases 
Any_three_phases = set(Real_World_Method_list) or set(HM_list) or set(Sensitivity_list)
print(len(Any_three_phases))
All_three_phases = set(Real_World_Method_list) and set(HM_list) and set(Sensitivity_list)
print(len(All_three_phases))
# Out:
# 50
# 31

# %%
#Mentioned Missing Data
#Missing data analysis 
MM_list=Article_Review[(Article_Review.Include_in_Research=='Yes')&(Article_Review.Mention_Missing_Data!="No")].EndNote_Index
print(len(MM_list))
# Out:
# 81

# %%
#M means Missing, the papers are handled missing data papers 
HM_Papers=articles[articles['EndNote_ID'].isin(HM_list)]

# %%
HM_Years=HM_Papers['Year']
HM_Years_Count=HM_Years.value_counts().reset_index().rename(columns={'index':'Year','Year':'Assessed_Missingness_count'})
HM_Years_Count.sort_values('Year')
#Plot
sns.barplot(HM_Years_Count.Year,HM_Years_Count.Assessed_Missingness_count,color='gray')
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Year', ylabel='Assessed_Missingness_count'>

# %%
# Mentioned Missing Analysis
#M means Missing, the papers are handled missing data papers 
MM_Papers=articles[articles['EndNote_ID'].isin(MM_list)]
MM_Years=MM_Papers['Year']
MM_Years_Count=MM_Years.value_counts().reset_index().rename(columns={'index':'Year','Year':'Mentioned_Missingness_count'})
MM_Years_Count.sort_values('Year')
#Plot
sns.barplot(MM_Years_Count.Year,MM_Years_Count.Mentioned_Missingness_count,color='gray')
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Year', ylabel='Mentioned_Missingness_count'>

# %%
Graph_Years=I_Years_Count.sort_values("Year").merge(MM_Years_Count,on='Year',how="left").merge(HM_Years_Count,on='Year',how="left").merge(RWM_Years_Count,on='Year',how='left').merge(S_Years_Count,on='Year',how='left').fillna(0)
Graph_Years
# Out:
#    index  Year  included_number    epoch hatches   colors  \
# 0      9  2010                4  epoch 1       /  #08519c
# 1      6  2011                9  epoch 1       /  #08519c
# 2      8  2012                6  epoch 1       /  #08519c
# 3      4  2013               16  epoch 1       /  #08519c
# 4      7  2014                7  epoch 2      //  #3182bd
# 5      5  2015               11  epoch 2      //  #3182bd
# 6      3  2016               17  epoch 2      //  #3182bd
# 7      0  2017               35  epoch 3     ///  #6baed6
# 8      1  2018               35  epoch 4    ////  #bdd7e7
# 9      2  2019               35  epoch 5   /////  #eff3ff
#
#    Mentioned_Missingness_count  Assessed_Missingness_count  RWM_count  \
# 0                            2                         1.0        1.0
# 1                            1                         0.0        1.0
# 2                            3                         2.0        0.0
# 3                           10                         5.0        6.0
# 4                            3                         1.0        2.0
# 5                            4                         4.0        5.0
# 6                            5                         2.0        6.0
# 7                           21                        13.0       14.0
# 8                           15                         6.0        8.0
# 9                           17                         5.0        7.0
#
#    Sensitivity_Analysis_Count
# 0                         0.0
# 1                         1.0
# 2                         0.0
# 3                         3.0
# 4                         1.0
# 5                         3.0
# 6                         6.0
# 7                        10.0
# 8                         3.0
# 9                         4.0

# %%
Graph_Years['RWM_%']=Graph_Years.RWM_count/Graph_Years.included_number
Graph_Years['MM_%']=Graph_Years.Mentioned_Missingness_count/Graph_Years.included_number
Graph_Years['HM_%']=Graph_Years.Assessed_Missingness_count/Graph_Years.included_number
Graph_Years['Sensitivity_analysis_%']=Graph_Years.Assessed_Missingness_count/Graph_Years.included_number

# %%
Graph_Years
# Out:
#    index  Year  included_number    epoch hatches   colors  \
# 0      9  2010                4  epoch 1       /  #08519c
# 1      6  2011                9  epoch 1       /  #08519c
# 2      8  2012                6  epoch 1       /  #08519c
# 3      4  2013               16  epoch 1       /  #08519c
# 4      7  2014                7  epoch 2      //  #3182bd
# 5      5  2015               11  epoch 2      //  #3182bd
# 6      3  2016               17  epoch 2      //  #3182bd
# 7      0  2017               35  epoch 3     ///  #6baed6
# 8      1  2018               35  epoch 4    ////  #bdd7e7
# 9      2  2019               35  epoch 5   /////  #eff3ff
#
#    Mentioned_Missingness_count  Assessed_Missingness_count  RWM_count  \
# 0                            2                         1.0        1.0
# 1                            1                         0.0        1.0
# 2                            3                         2.0        0.0
# 3                           10                         5.0        6.0
# 4                            3                         1.0        2.0
# 5                            4                         4.0        5.0
# 6                            5                         2.0        6.0
# 7                           21                        13.0       14.0
# 8                           15                         6.0        8.0
# 9                           17                         5.0        7.0
#
#    Sensitivity_Analysis_Count     RWM_%      MM_%      HM_%  \
# 0                         0.0  0.250000  0.500000  0.250000
# 1                         1.0  0.111111  0.111111  0.000000
# 2                         0.0  0.000000  0.500000  0.333333
# 3                         3.0  0.375000  0.625000  0.312500
# 4                         1.0  0.285714  0.428571  0.142857
# 5                         3.0  0.454545  0.363636  0.363636
# 6                         6.0  0.352941  0.294118  0.117647
# 7                        10.0  0.400000  0.600000  0.371429
# 8                         3.0  0.228571  0.428571  0.171429
# 9                         4.0  0.200000  0.485714  0.142857
#
#    Sensitivity_analysis_%
# 0                0.250000
# 1                0.000000
# 2                0.333333
# 3                0.312500
# 4                0.142857
# 5                0.363636
# 6                0.117647
# 7                0.371429
# 8                0.171429
# 9                0.142857

# %%
RWE_or_S_List=list(set(Real_World_Method_list) | set(Sensitivity_list))
RWE_or_S_Papers=articles[articles['EndNote_ID'].isin(RWE_or_S_List)]
RS_Years=RWE_or_S_Papers['Year']
RS_Years_Count=RS_Years.value_counts().reset_index().rename(columns={'index':'Year','Year':'Sensitivity_analysis_or Real-World_Methods_Count'})
RS_Years_Count.sort_values('Year')
# Out:
#    Year  Sensitivity_analysis_or Real-World_Methods_Count
# 8  2010                                                 1
# 7  2011                                                 1
# 3  2013                                                 6
# 6  2014                                                 2
# 5  2015                                                 5
# 4  2016                                                 6
# 0  2017                                                14
# 1  2018                                                 8
# 2  2019                                                 7

# %%
RWE_or_S_Litst_or_HM_list = set(Real_World_Method_list)|set(Sensitivity_list)|set(HM_list)
RWE_or_S_Litst_or_HM_list=S_Years.value_counts().reset_index().rename(columns={'index':'Year','Year':'All three components'})
RS_Years_Count.sort_values('Year') #50 /175 = 28.6%
# Out:
#    Year  Sensitivity_analysis_or Real-World_Methods_Count
# 8  2010                                                 1
# 7  2011                                                 1
# 3  2013                                                 6
# 6  2014                                                 2
# 5  2015                                                 5
# 4  2016                                                 6
# 0  2017                                                14
# 1  2018                                                 8
# 2  2019                                                 7

# %%
# how many papers did three phases of analysis 
set(Real_World_Method_list).intersection(set(Sensitivity_list)).intersection(set(HM_Papers.EndNote_ID))
# Out:
# {1230.0,
#  1812.0,
#  2758.0,
#  3017.0,
#  3168.0,
#  3413.0,
#  3876.0,
#  4290.0,
#  4528.0,
#  4821.0,
#  4912.0,
#  5068.0,
#  5246.0}

# %%
Traditional_regression_list=[1564	,
4297	,
3532	,
3484	,
4492	,
3697	,
4678	,
3197	,
1259	,
1717	,
3648	,
4782	,
1449	,
3576	,
3080	,
2463	,
4634	,
1220	,
2696	,
957	,
1835	,
1901	,
4362	,
4427	,
2212	,
4926	,
1930	,
4857	,
1822	,
700	,
3497	,
2851	,
3089	,
3257	,
3432	,
2991	,
3905	,
1959	,
2469	,
2457	,
4835	,
1129	,
690	,
4419	,
2634	,
3531	,
2015	,
730	,
5567	,
4517	,
3687	,
4890	,
1905	,
5741	,
1506	,
4052	,
5661	,
3962	,
4166	,
3883	,
4355	,
4772	,
4065	,
915	,
691	,
4940	,
2716	,
5833	,
4873	,
4522	,
1458	,
5605	,
4086	,
1418	,
928	,
2291	,
1572	,
3876	,
2778	,
4526	,
4821	,
4294	,
3591	,
804	,
3043	,
5017	,
4328	,
2148	,
3087	,
5792	,
3428	,
4917	,
5805	,
3587	,
4342	,
5790	,
]

# %%
# traditional regression papers count
len(Traditional_regression_list)
# Out:
# 96

# %%
traditional_regression_without_RWE=list(set(Traditional_regression_list)-set(Real_World_Method_list))
traditional_regression_without_RWE_paper = articles[articles['EndNote_ID'].isin(traditional_regression_without_RWE)]

# %%
traditional_regression_without_sensitivity=list(set(Traditional_regression_list)-set(Sensitivity_list))
len(traditional_regression_without_sensitivity)
# Out:
# 84

# %%
Survival_analysis_list=[1230	,
5515	,
3304	,
4012	,
5454	,
3115	,
4382	,
1504	,
1835	,
2212	,
5783	,
1822	,
4692	,
4528	,
4762	,
906	,
5626	,
2597	,
3168	,
4912	,
2087	,
5068	,
730	,
2198	,
5741	,
2802	,
4307	,
5505	,
2716	,
5069	,
5833	,
2758	,
4989	,
3413	,
1812	,
3043	,
3743	,
901	,
4328	,
3587	,
4342	]

# %%
len(Survival_analysis_list)
# Out:
# 41

# %%
# 
Survival_without_RWE=list(set(Survival_analysis_list)-set(Real_World_Method_list))
Survival_without_RWE_paper = articles[articles['EndNote_ID'].isin(Survival_without_RWE)]
len(Survival_without_RWE)
# Out:
# 26

# %%
#c=articles[articles['EndNote_ID'].isin(RWE_not_S_List)]
#RnotS_Years=RWE_not_S_Papers['Year']
#RnotS_Years_Count=RnotS_Years.value_counts().reset_index().rename(columns={'index':'Year','Year':'Real-World_Methods_Count not Sensitivity analysis'})
#RnotS_Years_Count.sort_values('Year')

# %% [markdown]
# ### Add impact factor analysis

# %%
HM_Impact=mapped[mapped.EndNote_ID.isin(HM_list)]
HM_Impact
# Out:
#      EndNote_ID                                       Article_Name  \
# 157        4012  Long-term outcomes of endoscopic resection and...
# 117        3187  Quick Sequential Organ Failure Assessment and ...
# 119        3187  Quick Sequential Organ Failure Assessment and ...
# 118        3187  Quick Sequential Organ Failure Assessment and ...
# 116        3187  Quick Sequential Organ Failure Assessment and ...
# 115        3168  Obesity in Older People With and Without Condi...
# 162        4166  Performance of the CURB-65 Score in Predicting...
# 204        5068  Association of Neighborhood Socioeconomic Cont...
# 216        5626  Comparative Toxicity and Effectiveness of Tras...
# 163        4290  Neonatal Outcomes Associated With Placental Ab...
# 27         1279  Angiotensin receptor blockers: are they relate...
# 224        5833  Comparative Effectiveness and Resource Usage i...
# 24          957  Statin use and the risk of colorectal cancer i...
# 59         1835  Total psoas area predicts medium-term mortalit...
# 58         1835  Total psoas area predicts medium-term mortalit...
# 133        3413  Hyperuricemia is associated with increased hos...
# 132        3413  Hyperuricemia is associated with increased hos...
# 106        3017  Insurance status is a predictor of failure to ...
# 103        3017  Insurance status is a predictor of failure to ...
# 108        3017  Insurance status is a predictor of failure to ...
# 107        3017  Insurance status is a predictor of failure to ...
# 105        3017  Insurance status is a predictor of failure to ...
# 19         4762  Fracture risk in type 2 diabetic patients: A c...
# 18         3591  Diagnostic intervals and its association with ...
# 51         2015  What proportion of patients with psychosis is ...
# 55         3576  Protocol for a prospective observational study...
# 49         1812  Effectiveness, safety and costs of thromboembo...
# 7          2758  The effect of anatomic location of injury on m...
# 12         2758  The effect of anatomic location of injury on m...
# 11         2758  The effect of anatomic location of injury on m...
# 9          2758  The effect of anatomic location of injury on m...
# 1           691  Development and validation of an ICD-10-based ...
# 10         2758  The effect of anatomic location of injury on m...
# 5           691  Development and validation of an ICD-10-based ...
# 6           691  Development and validation of an ICD-10-based ...
# 3           691  Development and validation of an ICD-10-based ...
# 4           691  Development and validation of an ICD-10-based ...
# 81         2469  Comparison of outcomes in severe pediatric tra...
# 82         2469  Comparison of outcomes in severe pediatric tra...
# 78         2457  The impact of Glasgow Coma Scale-age prognosis...
# 191        4821  Association of worksite wellness center attend...
# 99         2991  Validation of Prognostic Models to Predict Ear...
# 151        4528  Effect of bisphosphonates on knee replacement ...
# 150        3743  The risk of cardiovascular disease in systemic...
# 149        3531  The unclosing premature mortality gap in gout:...
# 187        4678  Association between body mass index and qualit...
# 197        4912  Temporal Trends of Venous Thromboembolism Risk...
# 207        5246  Neonatal health of infants born to mothers wit...
# 155        3876  Effect of psoriasis severity on hypertension c...
# 110        3080  Trends and Outcomes of Pediatric Vascular Inju...
# 109        3080  Trends and Outcomes of Pediatric Vascular Inju...
# 63         2001  Obesity in pediatric specialty clinics: an und...
# 104        3017  Insurance status is a predictor of failure to ...
# 8          2758  The effect of anatomic location of injury on m...
# 2           691  Development and validation of an ICD-10-based ...
# 54         3576  Protocol for a prospective observational study...
# 50         2015  What proportion of patients with psychosis is ...
# 48         1812  Effectiveness, safety and costs of thromboembo...
#
#                                               Abstract  Year  \
# 157  BACKGROUND AND AIMS: Endoscopic resection (ER)...  2019
# 117  OBJECTIVES: The Sepsis III clinical criteria f...  2017
# 119  OBJECTIVES: The Sepsis III clinical criteria f...  2017
# 118  OBJECTIVES: The Sepsis III clinical criteria f...  2017
# 116  OBJECTIVES: The Sepsis III clinical criteria f...  2017
# 115  BACKGROUND: Moderate obesity in later life may...  2017
# 162  STUDY OBJECTIVE: Confusion, uremia, elevated r...  2019
# 204  BACKGROUND: Cardiac rehabilitation (CR) is und...  2017
# 216  Purpose The combination of chemotherapy and tr...  2017
# 163  Placental abruption (early separation of the p...  2017
# 27   INTRODUCTION: Angiotensin receptor blockers (A...  2013
# 224  BACKGROUND: Weekly (qw) nanoparticle albumin-b...  2017
# 24   There is extensive debate regarding the protec...  2019
# 59   BACKGROUND: Analytic morphometry is a novel co...  2018
# 58   BACKGROUND: Analytic morphometry is a novel co...  2018
# 133  BACKGROUND AND AIM: Chronic hyperuricemia is r...  2016
# 132  BACKGROUND AND AIM: Chronic hyperuricemia is r...  2016
# 106  BACKGROUND: Disparities in outcomes for uninsu...  2013
# 103  BACKGROUND: Disparities in outcomes for uninsu...  2013
# 108  BACKGROUND: Disparities in outcomes for uninsu...  2013
# 107  BACKGROUND: Disparities in outcomes for uninsu...  2013
# 105  BACKGROUND: Disparities in outcomes for uninsu...  2013
# 19   BACKGROUND: An increased fracture risk has bee...  2018
# 18   Rapid diagnostic pathways for cancer have been...  2015
# 51   OBJECTIVE: The proportion of people with menta...  2017
# 55   INTRODUCTION: Frailty is of increasing importa...  2019
# 49   PURPOSE: Atrial fibrillation is the most commo...  2016
# 7    INTRODUCTION: Injury is a significant cause of...  2017
# 12   INTRODUCTION: Injury is a significant cause of...  2017
# 11   INTRODUCTION: Injury is a significant cause of...  2017
# 9    INTRODUCTION: Injury is a significant cause of...  2017
# 1    BACKGROUND: There was no established disabilit...  2018
# 10   INTRODUCTION: Injury is a significant cause of...  2017
# 5    BACKGROUND: There was no established disabilit...  2018
# 6    BACKGROUND: There was no established disabilit...  2018
# 3    BACKGROUND: There was no established disabilit...  2018
# 4    BACKGROUND: There was no established disabilit...  2018
# 81   BACKGROUND: In addition to trauma center level...  2017
# 82   BACKGROUND: In addition to trauma center level...  2017
# 78   BACKGROUND: As the population ages, increasing...  2017
# 191  OBJECTIVE: To assess the impact of wellness ce...  2015
# 99   OBJECTIVE: Numerous scores have been developed...  2018
# 151  PURPOSE: Bone remodelling as a therapeutic tar...  2018
# 150  OBJECTIVES: To evaluate the risk of incident m...  2013
# 149  OBJECTIVE: Gout, the most common inflammatory ...  2017
# 187  BACKGROUND & AIMS: Little is known about the a...  2013
# 197  OBJECTIVE: Giant cell arteritis (GCA) and the ...  2017
# 207  BACKGROUND: Maternal asthma is associated with...  2014
# 155  IMPORTANCE: Hypertension is prevalent among pa...  2015
# 110  BACKGROUND: According to the Center for Diseas...  2019
# 109  BACKGROUND: According to the Center for Diseas...  2019
# 63   OBJECTIVES: (a) To examine the prevalence of o...  2012
# 104  BACKGROUND: Disparities in outcomes for uninsu...  2013
# 8    INTRODUCTION: Injury is a significant cause of...  2017
# 2    BACKGROUND: There was no established disabilit...  2018
# 54   INTRODUCTION: Frailty is of increasing importa...  2019
# 50   OBJECTIVE: The proportion of people with menta...  2017
# 48   PURPOSE: Atrial fibrillation is the most commo...  2016
#
#                                                Journal  PubMed_ID Language  \
# 157                         GASTROINTESTINAL ENDOSCOPY   30576649      eng
# 117                             CRITICAL CARE MEDICINE   28759474      eng
# 119                             CRITICAL CARE MEDICINE   28759474      eng
# 118                             CRITICAL CARE MEDICINE   28759474      eng
# 116                             CRITICAL CARE MEDICINE   28759474      eng
# 115  JOURNALS OF GERONTOLOGY SERIES A: BIOLOGICAL S...   27492450      eng
# 162                       ANNALS OF EMERGENCY MEDICINE   30078659      eng
# 204                                   J AM HEART ASSOC   29021267      eng
# 216                       JOURNAL OF CLINICAL ONCOLOGY   28727517      eng
# 163                   AMERICAN JOURNAL OF EPIDEMIOLOGY   28595292      eng
# 27                             JOURNAL OF HYPERTENSION   23822929      eng
# 224                               CLINICAL LUNG CANCER   28117221      eng
# 24                                  SCIENTIFIC REPORTS   31537841      eng
# 59                         JOURNAL OF VASCULAR SURGERY   30064842      eng
# 58                         JOURNAL OF VASCULAR SURGERY   30064842      eng
# 133  NUTRITION, METABOLISM, AND CARDIOVASCULAR DISE...   27555289      eng
# 132  NUTRITION, METABOLISM, AND CARDIOVASCULAR DISE...   27555289      eng
# 106                           J TRAUMA ACUTE CARE SURG   24064890      eng
# 103                           J TRAUMA ACUTE CARE SURG   24064890      eng
# 108                           J TRAUMA ACUTE CARE SURG   24064890      eng
# 107                           J TRAUMA ACUTE CARE SURG   24064890      eng
# 105                           J TRAUMA ACUTE CARE SURG   24064890      eng
# 19                                            PLOS ONE   30192850      eng
# 18                                            PLOS ONE   25933397      eng
# 51                                            BMJ OPEN   28279995      eng
# 55                                            BMJ OPEN   30782738      eng
# 49                                            BMJ OPEN   26823179      eng
# 7                                               INJURY   28551054      eng
# 12                                              INJURY   28551054      eng
# 11                                              INJURY   28551054      eng
# 9                                               INJURY   28551054      eng
# 1                                               INJURY   29352592      eng
# 10                                              INJURY   28551054      eng
# 5                                               INJURY   29352592      eng
# 6                                               INJURY   29352592      eng
# 3                                               INJURY   29352592      eng
# 4                                               INJURY   29352592      eng
# 81                        JOURNAL OF PEDIATRIC SURGERY   28196660      eng
# 82                        JOURNAL OF PEDIATRIC SURGERY   28196660      eng
# 78                        JOURNAL OF SURGICAL RESEARCH   28807194      eng
# 191  JOURNAL OF OCCUPATIONAL AND ENVIRONMENTAL MEDI...   25742528      eng
# 99                                  WORLD NEUROSURGERY   29054778      eng
# 151                   ANNALS OF THE RHEUMATIC DISEASES   28988204      eng
# 150                   ANNALS OF THE RHEUMATIC DISEASES   22904260      eng
# 149                   ANNALS OF THE RHEUMATIC DISEASES   28122760      eng
# 187           CLINICAL GASTROENTEROLOGY AND HEPATOLOGY   23811246      eng
# 197                                ARTHRITIS RHEUMATOL   28029234      eng
# 207         JOURNAL OF ALLERGY AND CLINICAL IMMUNOLOGY   23916153      eng
# 155                                      JAMA DERMATOL   25322196      eng
# 110                         ANNALS OF VASCULAR SURGERY   30476614      eng
# 109                         ANNALS OF VASCULAR SURGERY   30476614      eng
# 63                                 CLINICAL PEDIATRICS   22930781      eng
# 104                           J TRAUMA ACUTE CARE SURG   24064890      eng
# 8                                               INJURY   28551054      eng
# 2                                               INJURY   29352592      eng
# 54                                            BMJ OPEN   30782738      eng
# 50                                            BMJ OPEN   28279995      eng
# 48                                            BMJ OPEN   26823179      eng
#
#                                     DOI       ISSN  ï»¿_ID  \
# 157           10.1016/j.gie.2018.12.010  0016-5107    1932
# 117        10.1097/ccm.0000000000002622  0090-3493     408
# 119        10.1097/ccm.0000000000002622  0090-3493     875
# 118        10.1097/ccm.0000000000002622  0090-3493     508
# 116        10.1097/ccm.0000000000002622  0090-3493      18
# 115               10.1093/gerona/glw147  1079-5006    1540
# 162   10.1016/j.annemergmed.2018.06.017  0196-0644    1957
# 204             10.1161/jaha.117.006260  2047-9980    3198
# 216            10.1200/jco.2016.71.4345  0732-183X    2353
# 163                  10.1093/aje/kwx202  0002-9262    1172
# 27         10.1097/HJH.0b013e3283621ea3  0263-6352    4300
# 224          10.1016/j.cllc.2016.12.008  1525-7304    2467
# 24           10.1038/s41598-019-49877-5  2045-2322    1566
# 59            10.1016/j.jvs.2018.01.040  0741-5214    4309
# 58            10.1016/j.jvs.2018.01.040  0741-5214    1989
# 133        10.1016/j.numecd.2016.06.008  0939-4753    4545
# 132        10.1016/j.numecd.2016.06.008  0939-4753    3250
# 106         10.1097/TA.0b013e3182a53aaa  2163-0755     554
# 103         10.1097/TA.0b013e3182a53aaa  2163-0755      63
# 108         10.1097/TA.0b013e3182a53aaa  2163-0755    2040
# 107         10.1097/TA.0b013e3182a53aaa  2163-0755     958
# 105         10.1097/TA.0b013e3182a53aaa  2163-0755     433
# 19         10.1371/journal.pone.0203533  1932-6203    1613
# 18         10.1371/journal.pone.0126608  1932-6203    1613
# 51          10.1136/bmjopen-2016-013113  2044-6055     572
# 55          10.1136/bmjopen-2018-024682  2044-6055     572
# 49          10.1136/bmjopen-2015-010144  2044-6055     572
# 7          10.1016/j.injury.2017.05.023  0020-1383      85
# 12         10.1016/j.injury.2017.05.023  0020-1383    2082
# 11         10.1016/j.injury.2017.05.023  0020-1383     991
# 9          10.1016/j.injury.2017.05.023  0020-1383     445
# 1          10.1016/j.injury.2017.12.021  0020-1383      85
# 10         10.1016/j.injury.2017.05.023  0020-1383     577
# 5          10.1016/j.injury.2017.12.021  0020-1383     991
# 6          10.1016/j.injury.2017.12.021  0020-1383    2082
# 3          10.1016/j.injury.2017.12.021  0020-1383     445
# 4          10.1016/j.injury.2017.12.021  0020-1383     577
# 81       10.1016/j.jpedsurg.2017.01.066  0022-3468    1655
# 82       10.1016/j.jpedsurg.2017.01.066  0022-3468    2089
# 78            10.1016/j.jss.2017.04.026  0022-4804    2119
# 191        10.1097/jom.0000000000000392  1076-2752    1311
# 99           10.1016/j.wneu.2017.10.039  1878-8750    2125
# 151     10.1136/annrheumdis-2017-211811  0003-4967    2361
# 150     10.1136/annrheumdis-2012-202007  0003-4967    2361
# 149     10.1136/annrheumdis-2016-210588  0003-4967    2361
# 187           10.1016/j.cgh.2013.05.037  1542-3565    1926
# 197                   10.1002/art.39847  2326-5191    2379
# 207          10.1016/j.jaci.2013.06.012  0091-6749    1524
# 155      10.1001/jamadermatol.2014.2094  2168-6068    3531
# 110          10.1016/j.avsg.2018.09.006  0890-5096    4402
# 109          10.1016/j.avsg.2018.09.006  0890-5096    2178
# 63             10.1177/0009922812458353  0009-9228    1753
# 104         10.1097/TA.0b013e3182a53aaa  2163-0755     210
# 8          10.1016/j.injury.2017.05.023  0020-1383     280
# 2          10.1016/j.injury.2017.12.021  0020-1383     280
# 54          10.1136/bmjopen-2018-024682  2044-6055     262
# 50          10.1136/bmjopen-2016-013113  2044-6055     262
# 48          10.1136/bmjopen-2015-010144  2044-6055     262
#
#                                           Journal_name      eISSN  \
# 157                         GASTROINTESTINAL ENDOSCOPY  1097-6779
# 117                             CRITICAL CARE MEDICINE  1530-0293
# 119                             CRITICAL CARE MEDICINE  1530-0293
# 118                             CRITICAL CARE MEDICINE  1530-0293
# 116                             CRITICAL CARE MEDICINE  1530-0293
# 115  JOURNALS OF GERONTOLOGY SERIES A-BIOLOGICAL SC...  1758-535X
# 162                       ANNALS OF EMERGENCY MEDICINE  1097-6760
# 204          JOURNAL OF THE AMERICAN HEART ASSOCIATION  2047-9980
# 216                       JOURNAL OF CLINICAL ONCOLOGY  1527-7755
# 163                   AMERICAN JOURNAL OF EPIDEMIOLOGY  1476-6256
# 27                             JOURNAL OF HYPERTENSION  1473-5598
# 224                               CLINICAL LUNG CANCER  1938-0690
# 24                                  SCIENTIFIC REPORTS  2045-2322
# 59                         JOURNAL OF VASCULAR SURGERY        NaN
# 58                         JOURNAL OF VASCULAR SURGERY        NaN
# 133   NUTRITION METABOLISM AND CARDIOVASCULAR DISEASES  1590-3729
# 132   NUTRITION METABOLISM AND CARDIOVASCULAR DISEASES  1590-3729
# 106           JOURNAL OF TRAUMA AND ACUTE CARE SURGERY  2163-0763
# 103           JOURNAL OF TRAUMA AND ACUTE CARE SURGERY  2163-0763
# 108           JOURNAL OF TRAUMA AND ACUTE CARE SURGERY  2163-0763
# 107           JOURNAL OF TRAUMA AND ACUTE CARE SURGERY  2163-0763
# 105           JOURNAL OF TRAUMA AND ACUTE CARE SURGERY  2163-0763
# 19                                            PLOS ONE  1932-6203
# 18                                            PLOS ONE  1932-6203
# 51                                            BMJ OPEN  2044-6055
# 55                                            BMJ OPEN  2044-6055
# 49                                            BMJ OPEN  2044-6055
# 7    INJURY-INTERNATIONAL JOURNAL OF THE CARE OF TH...  1879-0267
# 12   INJURY-INTERNATIONAL JOURNAL OF THE CARE OF TH...  1879-0267
# 11   INJURY-INTERNATIONAL JOURNAL OF THE CARE OF TH...  1879-0267
# 9    INJURY-INTERNATIONAL JOURNAL OF THE CARE OF TH...  1879-0267
# 1    INJURY-INTERNATIONAL JOURNAL OF THE CARE OF TH...  1879-0267
# 10   INJURY-INTERNATIONAL JOURNAL OF THE CARE OF TH...  1879-0267
# 5    INJURY-INTERNATIONAL JOURNAL OF THE CARE OF TH...  1879-0267
# 6    INJURY-INTERNATIONAL JOURNAL OF THE CARE OF TH...  1879-0267
# 3    INJURY-INTERNATIONAL JOURNAL OF THE CARE OF TH...  1879-0267
# 4    INJURY-INTERNATIONAL JOURNAL OF THE CARE OF TH...  1879-0267
# 81                        JOURNAL OF PEDIATRIC SURGERY  1531-5037
# 82                        JOURNAL OF PEDIATRIC SURGERY  1531-5037
# 78                        JOURNAL OF SURGICAL RESEARCH  1095-8673
# 191  JOURNAL OF OCCUPATIONAL AND ENVIRONMENTAL MEDI...  1536-5948
# 99                                  WORLD NEUROSURGERY  1878-8769
# 151                   ANNALS OF THE RHEUMATIC DISEASES  1468-2060
# 150                   ANNALS OF THE RHEUMATIC DISEASES  1468-2060
# 149                   ANNALS OF THE RHEUMATIC DISEASES  1468-2060
# 187           CLINICAL GASTROENTEROLOGY AND HEPATOLOGY  1542-7714
# 197                           ARTHRITIS & RHEUMATOLOGY  2326-5205
# 207         JOURNAL OF ALLERGY AND CLINICAL IMMUNOLOGY  1097-6825
# 155                                   JAMA DERMATOLOGY  2168-6084
# 110                         ANNALS OF VASCULAR SURGERY  1615-5947
# 109                         ANNALS OF VASCULAR SURGERY  1615-5947
# 63                                 CLINICAL PEDIATRICS  1938-2707
# 104           JOURNAL OF TRAUMA AND ACUTE CARE SURGERY  2163-0763
# 8    INJURY-INTERNATIONAL JOURNAL OF THE CARE OF TH...  1879-0267
# 2    INJURY-INTERNATIONAL JOURNAL OF THE CARE OF TH...  1879-0267
# 54                                            BMJ OPEN  2044-6055
# 50                                            BMJ OPEN  2044-6055
# 48                                            BMJ OPEN  2044-6055
#
#                                               Category Total_Citations  \
# 157               GASTROENTEROLOGY & HEPATOLOGY - SCIE          28,955
# 117                      CRITICAL CARE MEDICINE - SCIE          47,631
# 119                      CRITICAL CARE MEDICINE - SCIE          47,631
# 118                      CRITICAL CARE MEDICINE - SCIE          47,631
# 116                      CRITICAL CARE MEDICINE - SCIE          47,631
# 115                    GERIATRICS & GERONTOLOGY - SCIE          26,686
# 162                          EMERGENCY MEDICINE - SCIE          14,808
# 204            CARDIAC & CARDIOVASCULAR SYSTEMS - SCIE          26,960
# 216                                    ONCOLOGY - SCIE         189,443
# 163  PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH - ...          43,617
# 27                  PERIPHERAL VASCULAR DISEASE - SCIE          19,652
# 224                                    ONCOLOGY - SCIE           4,202
# 24                   MULTIDISCIPLINARY SCIENCES - SCIE         541,615
# 59                  PERIPHERAL VASCULAR DISEASE - SCIE          31,991
# 58                                      SURGERY - SCIE          31,991
# 133                  ENDOCRINOLOGY & METABOLISM - SCIE           7,701
# 132  ENDOCRINOLOGY & METABOLISM - SCIE; CARDIAC & C...           7,701
# 106                      CRITICAL CARE MEDICINE - SCIE          11,459
# 103                      CRITICAL CARE MEDICINE - SCIE          11,459
# 108                                     SURGERY - SCIE          11,459
# 107                      CRITICAL CARE MEDICINE - SCIE          11,459
# 105                      CRITICAL CARE MEDICINE - SCIE          11,459
# 19                   MULTIDISCIPLINARY SCIENCES - SCIE         857,723
# 18                   MULTIDISCIPLINARY SCIENCES - SCIE         857,723
# 51                 MEDICINE, GENERAL & INTERNAL - SCIE          55,068
# 55                 MEDICINE, GENERAL & INTERNAL - SCIE          55,068
# 49                 MEDICINE, GENERAL & INTERNAL - SCIE          55,068
# 7                        CRITICAL CARE MEDICINE - SCIE          19,692
# 12           SURGERY - SCIE; EMERGENCY MEDICINE - SCIE          19,692
# 11                       CRITICAL CARE MEDICINE - SCIE          19,692
# 9                        CRITICAL CARE MEDICINE - SCIE          19,692
# 1                        CRITICAL CARE MEDICINE - SCIE          19,692
# 10                       CRITICAL CARE MEDICINE - SCIE          19,692
# 5                        CRITICAL CARE MEDICINE - SCIE          19,692
# 6            SURGERY - SCIE; EMERGENCY MEDICINE - SCIE          19,692
# 3                        CRITICAL CARE MEDICINE - SCIE          19,692
# 4                        CRITICAL CARE MEDICINE - SCIE          19,692
# 81                                   PEDIATRICS - SCIE          20,364
# 82                                      SURGERY - SCIE          20,364
# 78                                      SURGERY - SCIE          17,062
# 191  PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH - ...           8,499
# 99                                      SURGERY - SCIE          23,506
# 151                                RHEUMATOLOGY - SCIE          58,006
# 150                                RHEUMATOLOGY - SCIE          58,006
# 149                                RHEUMATOLOGY - SCIE          58,006
# 187               GASTROENTEROLOGY & HEPATOLOGY - SCIE          24,144
# 197                                RHEUMATOLOGY - SCIE          16,730
# 207                                     ALLERGY - SCIE          63,614
# 155                                 DERMATOLOGY - SCIE           8,448
# 110                 PERIPHERAL VASCULAR DISEASE - SCIE           7,121
# 109                                     SURGERY - SCIE           7,121
# 63                                   PEDIATRICS - SCIE           4,416
# 104                      CRITICAL CARE MEDICINE - SCIE             334
# 8                        CRITICAL CARE MEDICINE - SCIE             500
# 2                        CRITICAL CARE MEDICINE - SCIE             500
# 54                 MEDICINE, GENERAL & INTERNAL - SCIE            3266
# 50                 MEDICINE, GENERAL & INTERNAL - SCIE            3266
# 48                 MEDICINE, GENERAL & INTERNAL - SCIE            3266
#
#     2020_JIF JIF_Quartile  2020 _JCI Percentage_of_OA_Gold
# 157     9.43           Q1       1.59                 2.45%
# 117     7.60           Q1       1.66                 5.38%
# 119     7.60           Q1       1.66                 5.38%
# 118     7.60           Q1       1.66                 5.38%
# 116     7.60           Q1       1.66                 5.38%
# 115     6.05           Q1       1.82                14.16%
# 162     5.72           Q1       2.64                 4.02%
# 204     5.50           Q1       1.14               100.00%
# 216    44.54           Q1       5.25                15.70%
# 163     4.90           Q1       1.79                15.24%
# 27      4.84           Q2       0.97                 4.81%
# 224     4.79           Q2       0.89                12.99%
# 24      4.38           Q1       0.80                99.96%
# 59      4.27           Q2       1.16                 2.70%
# 58      4.27           Q1       1.16                 2.70%
# 133     4.22           Q2       0.89                 6.64%
# 132     4.22       Q2; Q2       0.89                 6.64%
# 106     3.31           Q3       1.00                 1.22%
# 103     3.31           Q3       1.00                 1.22%
# 108     3.31           Q2       1.00                 1.22%
# 107     3.31           Q3       1.00                 1.22%
# 105     3.31           Q3       1.00                 1.22%
# 19      3.24           Q2       0.57               100.00%
# 18      3.24           Q2       0.57               100.00%
# 51      2.69           Q2       0.82                99.49%
# 55      2.69           Q2       0.82                99.49%
# 49      2.69           Q2       0.82                99.49%
# 7       2.59           Q3       0.86                 4.88%
# 12      2.59       Q2; Q2       0.86                 4.88%
# 11      2.59           Q3       0.86                 4.88%
# 9       2.59           Q3       0.86                 4.88%
# 1       2.59           Q3       0.86                 4.88%
# 10      2.59           Q3       0.86                 4.88%
# 5       2.59           Q3       0.86                 4.88%
# 6       2.59       Q2; Q2       0.86                 4.88%
# 3       2.59           Q3       0.86                 4.88%
# 4       2.59           Q3       0.86                 4.88%
# 81      2.55           Q2       1.00                 1.47%
# 82      2.55           Q2       1.00                 1.47%
# 78      2.19           Q3       0.84                 1.50%
# 191     2.16           Q3       0.70                 6.97%
# 99      2.10           Q3       0.63                 0.79%
# 151    19.10           Q1       3.82                32.83%
# 150    19.10           Q1       3.82                32.83%
# 149    19.10           Q1       3.82                32.83%
# 187    11.38           Q1       1.95                 8.96%
# 197    11.00           Q1       2.71                21.67%
# 207    10.79           Q1       2.35                18.04%
# 155    10.28           Q1       2.71                 7.41%
# 110     1.47           Q4       0.40                 2.80%
# 109     1.47           Q4       0.40                 2.80%
# 63      1.17           Q4       0.53                 1.07%
# 104     0.92          5.4       6.90                   306
# 8       0.87          7.8       8.80                   434
# 2       0.87          7.8       8.80                   434
# 54      0.82          3.8       6.80                  2686
# 50      0.82          3.8       6.80                  2686
# 48      0.82          3.8       6.80                  2686

# %%
### Create Epochs for analysis

# %%
Epoch=["2010-2013","2014-2016","2017","2018","2019"]

column_names=["Included_Number", "Real-World_Method", "Sensitivity_Analysis","Assessed_Missingness","Mentioned_Missingness"]

# %%
#manually entered
Epoch_df=[]
Epoch_df=pd.DataFrame(columns=column_names,index=Epoch)
Epoch_df.Included_Number=[4+9+6+16,7+11+17,35,35,35]
Epoch_df['Real-World_Method']=[1+1+0+6,2+5+6,14,8,7]
Epoch_df.Sensitivity_Analysis=[0+1+0+3,1+3+6,10,3,4]
Epoch_df.Assessed_Missingness=[1+0+2+5,1+4+2,14,8,5]
Epoch_df['Mentioned_Missingness']=[2+1+3+10,4+4+5,21,15,17]
#Epoch_df=Epoch_df.set_index(Epoch_df.Epoch.values)
Epoch_df
# Out:
#            Included_Number  Real-World_Method  Sensitivity_Analysis  \
# 2010-2013               35                  8                     4
# 2014-2016               35                 13                    10
# 2017                    35                 14                    10
# 2018                    35                  8                     3
# 2019                    35                  7                     4
#
#            Assessed_Missingness  Mentioned_Missingness
# 2010-2013                     8                     16
# 2014-2016                     7                     13
# 2017                         14                     21
# 2018                          8                     15
# 2019                          5                     17

# %%
Epoch_out=Epoch_df.reset_index(drop=True).T
Epoch_out.columns=Epoch
Epoch_out=Epoch_out.reset_index(drop=False)

# %%
(8+13+14+8+7)/175
# Out:
# 0.2857142857142857

# %%
(4+10+10+3+4)/175
# Out:
# 0.17714285714285713

# %% [markdown]
# ## Step 7 Percentage Analytics

# %%
import numpy as np
import pandas as pd

# %%
out = Epoch_out
out
# Out:
#                    index  2010-2013  2014-2016  2017  2018  2019
# 0        Included_Number         35         35    35    35    35
# 1      Real-World_Method          8         13    14     8     7
# 2   Sensitivity_Analysis          4         10    10     3     4
# 3   Assessed_Missingness          8          7    14     8     5
# 4  Mentioned_Missingness         16         13    21    15    17

# %%
#Change value 0 to 0.5 / Arc sin transform
out_transform=out.replace(0,0.5)
out_transform
# Out:
#                    index  2010-2013  2014-2016  2017  2018  2019
# 0        Included_Number         35         35    35    35    35
# 1      Real-World_Method          8         13    14     8     7
# 2   Sensitivity_Analysis          4         10    10     3     4
# 3   Assessed_Missingness          8          7    14     8     5
# 4  Mentioned_Missingness         16         13    21    15    17

# %%
interval = []
estimation = []
err_range = []
for i in range(1, 5):
    interval.append([])
    estimation.append([])
    err_range.append([])
    for j in range(1, 6):
        pHat = out_transform.iloc[i, j] / out_transform.iloc[0, j]
        lower = pHat - 1.96 * np.sqrt(pHat * (1 - pHat)) / np.sqrt(out_transform.iloc[0, j])
        if (lower < 0):
            lower=0
        higher = pHat + 1.96 * np.sqrt(pHat * (1 - pHat)) / np.sqrt(out_transform.iloc[0, j])
        err=1.96 * np.sqrt(pHat * (1 - pHat)) / np.sqrt(out_transform.iloc[0, j])
        
        interval[i - 1].append((round(lower, 4), round(higher, 4)))
        estimation[i - 1].append(round(pHat, 4))
        err_range[i - 1].append(round(err,4))

# %%
interval = pd.DataFrame(interval)
interval.columns =('2010-2013', '2014-2016', '2017', '2018', '2019')
interval.index= ('Analytic Real-World_Method', 'Sensitivity_Analysis','Assessed_Missing_Data','Mentioned_Missing_Data')

# %%
pHat = pd.DataFrame(estimation)
pHat.columns =('2010-2013', '2014-2016', '2017', '2018', '2019')
pHat.index = ('Analytic Real-World_Method', 'Sensitivity_Analysis','Assessed_Missing_Data','Mentioned_Missing_Data' )
pHat
# Out:
#                             2010-2013  2014-2016    2017    2018    2019
# Analytic Real-World_Method     0.2286     0.3714  0.4000  0.2286  0.2000
# Sensitivity_Analysis           0.1143     0.2857  0.2857  0.0857  0.1143
# Assessed_Missing_Data          0.2286     0.2000  0.4000  0.2286  0.1429
# Mentioned_Missing_Data         0.4571     0.3714  0.6000  0.4286  0.4857

# %%
interval
# Out:
#                                2010-2013         2014-2016              2017  \
# Real-World_Method       (0.0895, 0.3677)  (0.2113, 0.5315)  (0.2377, 0.5623)
# Sensitivity_Analysis    (0.0089, 0.2197)   (0.136, 0.4354)   (0.136, 0.4354)
# Assessed_Missing_Data   (0.0895, 0.3677)  (0.0675, 0.3325)  (0.2377, 0.5623)
# Mentioned_Missing_Data  (0.2921, 0.6222)  (0.2113, 0.5315)  (0.4377, 0.7623)
#
#                                     2018              2019
# Real-World_Method       (0.0895, 0.3677)  (0.0675, 0.3325)
# Sensitivity_Analysis         (0, 0.1785)  (0.0089, 0.2197)
# Assessed_Missing_Data   (0.0895, 0.3677)  (0.0269, 0.2588)
# Mentioned_Missing_Data  (0.2646, 0.5925)  (0.3201, 0.6513)

# %%
err_range
err_df = pd.DataFrame(err_range)
err_df.columns =('2010-2013', '2014-2016', '2017', '2018', '2019')
err_df.index = ( 'Analytic Real-World_Method', 'Sensitivity_Analysis','Assessed_Missing_Data','Mentioned_Missing_Data')
err_df
# Out:
#                             2010-2013  2014-2016    2017    2018    2019
# Analytic Real-World_Method     0.1391     0.1601  0.1623  0.1391  0.1325
# Sensitivity_Analysis           0.1054     0.1497  0.1497  0.0927  0.1054
# Assessed_Missing_Data          0.1391     0.1325  0.1623  0.1391  0.1159
# Mentioned_Missing_Data         0.1650     0.1601  0.1623  0.1640  0.1656

# %%
pHat = pd.DataFrame(estimation)
pHat.columns =('2010-2013', '2014-2016', '2017', '2018', '2019')
pHat.index = ('Analytic Real-World_Method', 'Sensitivity_Analysis','Assessed_Missing_Data','Mentioned_Missing_Data' )
pHat.to_csv('/Users/chenyuli/Research_Thesis/Analytics/20210707_pHat.csv')

# %%
plt.scatter(x=pHat.columns,y=pHat.iloc[0],c='dimgray')# Handled_Missing_Data
plt.scatter(x=pHat.columns,y=pHat.iloc[1],c='navy') # Real-World_Method
plt.scatter(x=pHat.columns,y=pHat.iloc[2],c='darkgreen') # Sensitivity_Analysis 
plt.ylabel('percentage of papers')
plt.xlabel('Epochs')
plt.title("Percentage of Methods Used (#papers)")
# Out:
# Text(0.5, 1.0, 'Percentage of Methods Used (#papers)')

# %%
pHat
print(pHat.iloc[0])
# Out:
# 2010-2013    0.2286
# 2014-2016    0.3714
# 2017         0.4000
# 2018         0.2286
# 2019         0.2000
# Name: Analytic Real-World_Method, dtype: float64

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
f, ax = plt.subplots()
x_ticks = ["2010-2013", "2014-2016", "2017", "2018", "2019"]
groups=['Assessed Missing Data','Analytic Real-World Method','Sensitivity_Analysis']
x_1 = np.arange(1, 6)-0.2
x_2 = x_1 +0.2
x_3 = x_2 +0.2
ax.errorbar(x=x_1, y=pHat.iloc[2], yerr=err_range[2], color="dimgray", capsize=3, linestyle="None", marker="s", markersize=7, mfc="dimgray", mec="dimgray")
ax.errorbar(x=x_2, y=pHat.iloc[0], yerr=err_range[0], color="navy", capsize=3, linestyle="None", marker="*", markersize=7, mfc="navy", mec="navy")
ax.errorbar(x=x_3, y=pHat.iloc[1], yerr=err_range[1], color="darkgreen", capsize=3, linestyle="None", marker="o", markersize=7, mfc="darkgreen", mec="darkgreen")
ax.set_xticks(x_2)
ax.set_xticklabels(x_ticks)
#plt.axhline(0.5,linestyle='--')
plt.ylim(0,1)
plt.ylabel('percentage of papers')
plt.xlabel('Epochs')
plt.title("Percentage of Methods Used (#papers used the methods/#papers included)")
plt.legend(groups)
plt.show()

# %% [markdown]
#    ## Step 8- Denominator Analysis
#    ### Table One

# %%
#pip install tableone

# %%
from tableone import TableOne, load_dataset
import pandas as pd

# %%
Article_Review=pd.read_csv('/Users/chenyuli/Research_Thesis/Validate/20210707/20210707_article_review.csv')   
#Article_Review=pd.read_excel('/Users/chenyuli/Research_Thesis/Validate/20210707/20210707_article_review.xlsx')
AR_Include=Article_Review[Article_Review.Include_in_Research=='Yes']
AR_Include
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      Review_ID  included_No  Reviewer_ID  EndNote_Index  Pubmed_ID  Year  \
# 4          5.0          1.0          NaN           3197   31167871  2019
# 10        11.0          2.0          NaN           1259   31306445  2019
# 11        12.0          3.0          NaN           1538   31881945  2019
# 12        13.0          4.0          NaN           3304   31332959  2019
# 14        15.0          5.0          NaN           1717   31210654  2019
# ..         ...          ...          ...            ...        ...   ...
# 484      381.0         31.0          NaN           4917   22871081  2012
# 490      387.0         32.0          NaN           5805   23756616  2013
# 492      389.0         33.0          NaN           3587   22484068  2013
# 494      391.0         34.0          NaN           4342   21801091  2011
# 495      392.0         35.0          NaN           5790   23165956  2013
#
#                                           Article_Name Review_Date  \
# 4    Trends in the incidence of testing for vitamin...    12/27/20
# 10   An interactive nomogram to predict healthcare-...    12/27/20
# 11   Sex differences in 10-year ischemic cardiovasc...    12/27/20
# 12   Clinical outcomes of external beam radiotherap...    12/27/20
# 14   Preoperative Pulmonary Function Test Results A...    12/27/20
# ..                                                 ...         ...
# 484  Likelihood of acute coronary syndrome in emerg...      7/7/21
# 490  Synchronization of administrations of chemothe...      7/7/21
# 492  Comparisons of 30-day mortalities and 90-day f...      7/7/21
# 494  Risk factors for emergent preterm delivery in ...      7/7/21
# 495  Zolpidem is independently associated with incr...      7/7/21
#
#        First_Author                                          Key_words  ...  \
# 4      Crowe, F. L.  Adult\nAged\nEthnic Groups\nFemale\nHumans\nIn...  ...
# 10        Zhang, M.  Acinetobacter Infections/diagnosis/epidemiolog...  ...
# 11         Yang, L.  Aged\nChina/epidemiology\nComorbidity\nDatabas...  ...
# 12       Lee, C. C.  Aged\nFollow-Up Studies\nHumans\nMale\nMiddle ...  ...
# 14    Burjek, N. E.  ng/*physiopathology\nMale\nMaximal Respiratory...  ...
# ..              ...                                                ...  ...
# 484     Ekelund, U.  Acute Coronary Syndrome/*complications/*diagno...  ...
# 490     Hill, J. W.  Adolescent\nAdult\nAged\nAmbulatory Care Facil...  ...
# 492      Kim, K. H.  Adult\nAged\nAged, 80 and over\nBody Mass Inde...  ...
# 494  Fishman, S. G.  Adult\nCohort Studies\nFemale\nGestational Age...  ...
# 495    Kolla, B. P.  Accidental Falls/*statistics & numerical data\...  ...
#
#     Association_Type Unit_of_Analysis Check_List   Mention_Missing_Data  \
# 4        Asosciation          patient         No        Yes, limitation
# 10       Association          Patient         No                     No
# 11       Association          patient         No                     No
# 12       Association          Patient         No                     No
# 14       Association          Patient         No                     No
# ..               ...              ...        ...                    ...
# 484      Associaiton          Patient         No     Yes, data cleaning
# 490      Association          Patient         No  Yes, data description
# 492      Association          Patient         No                     No
# 494      Associaiton          Patient         No                     No
# 495      Associaiton          Patient         No                     No
#
#     Handled_Missing_Data Rate_of_Article Include_in_Research Exclusion Reason  \
# 4                     No             NaN                 Yes              NaN
# 10                    No             NaN                 Yes              NaN
# 11                    No             NaN                 Yes              NaN
# 12                    No             NaN                 Yes              NaN
# 14                    No             NaN                 Yes              NaN
# ..                   ...             ...                 ...              ...
# 484        Yes, excluded             NaN                 Yes              NaN
# 490                   No             NaN                 Yes              NaN
# 492                   No             NaN                 Yes              NaN
# 494                   No             NaN                 Yes              NaN
# 495                   No             NaN                 Yes              NaN
#
#      Other_Notes Unnamed: 28
# 4            NaN         NaN
# 10           NaN         NaN
# 11           NaN         NaN
# 12           NaN         NaN
# 14           NaN         NaN
# ..           ...         ...
# 484          NaN         NaN
# 490          NaN         NaN
# 492          NaN         NaN
# 494          NaN         NaN
# 495          NaN         NaN
#
# [175 rows x 29 columns]

# %%
type(AR_Include)
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# pandas.core.frame.DataFrame

# %%
# Create Epoch for table one
AR_Include['Epoch']=AR_Include.Year

for i in range(len(AR_Include.Year)):
    if AR_Include.Year.iloc[i]==2010 or AR_Include.Year.iloc[i]==2011 or AR_Include.Year.iloc[i]==2012 or AR_Include.Year.iloc[i]==2013:
        AR_Include.Epoch.iloc[i]='2010-2013'
    elif AR_Include.Year.iloc[i]==2014 or AR_Include.Year.iloc[i]==2015 or AR_Include.Year.iloc[i]==2016:
        AR_Include.Epoch.iloc[i]='2014-2016'
    elif AR_Include.Year.iloc[i]==2017:
        AR_Include.Epoch.iloc[i]='2017'
    elif AR_Include.Year.iloc[i]==2018:
        AR_Include.Epoch.iloc[i]='2018'
    else:
        AR_Include.Epoch.iloc[i]='2019'
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-96-a3c74e54145d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AR_Include['Epoch']=AR_Include.Year
# /Users/chenyuli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/chenyuli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
AR_Include
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      Review_ID  included_No  Reviewer_ID  EndNote_Index  Pubmed_ID  Year  \
# 4          5.0          1.0          NaN           3197   31167871  2019
# 10        11.0          2.0          NaN           1259   31306445  2019
# 11        12.0          3.0          NaN           1538   31881945  2019
# 12        13.0          4.0          NaN           3304   31332959  2019
# 14        15.0          5.0          NaN           1717   31210654  2019
# ..         ...          ...          ...            ...        ...   ...
# 484      381.0         31.0          NaN           4917   22871081  2012
# 490      387.0         32.0          NaN           5805   23756616  2013
# 492      389.0         33.0          NaN           3587   22484068  2013
# 494      391.0         34.0          NaN           4342   21801091  2011
# 495      392.0         35.0          NaN           5790   23165956  2013
#
#                                           Article_Name Review_Date  \
# 4    Trends in the incidence of testing for vitamin...    12/27/20
# 10   An interactive nomogram to predict healthcare-...    12/27/20
# 11   Sex differences in 10-year ischemic cardiovasc...    12/27/20
# 12   Clinical outcomes of external beam radiotherap...    12/27/20
# 14   Preoperative Pulmonary Function Test Results A...    12/27/20
# ..                                                 ...         ...
# 484  Likelihood of acute coronary syndrome in emerg...      7/7/21
# 490  Synchronization of administrations of chemothe...      7/7/21
# 492  Comparisons of 30-day mortalities and 90-day f...      7/7/21
# 494  Risk factors for emergent preterm delivery in ...      7/7/21
# 495  Zolpidem is independently associated with incr...      7/7/21
#
#        First_Author                                          Key_words  ...  \
# 4      Crowe, F. L.  Adult\nAged\nEthnic Groups\nFemale\nHumans\nIn...  ...
# 10        Zhang, M.  Acinetobacter Infections/diagnosis/epidemiolog...  ...
# 11         Yang, L.  Aged\nChina/epidemiology\nComorbidity\nDatabas...  ...
# 12       Lee, C. C.  Aged\nFollow-Up Studies\nHumans\nMale\nMiddle ...  ...
# 14    Burjek, N. E.  ng/*physiopathology\nMale\nMaximal Respiratory...  ...
# ..              ...                                                ...  ...
# 484     Ekelund, U.  Acute Coronary Syndrome/*complications/*diagno...  ...
# 490     Hill, J. W.  Adolescent\nAdult\nAged\nAmbulatory Care Facil...  ...
# 492      Kim, K. H.  Adult\nAged\nAged, 80 and over\nBody Mass Inde...  ...
# 494  Fishman, S. G.  Adult\nCohort Studies\nFemale\nGestational Age...  ...
# 495    Kolla, B. P.  Accidental Falls/*statistics & numerical data\...  ...
#
#     Unit_of_Analysis Check_List   Mention_Missing_Data Handled_Missing_Data  \
# 4            patient         No        Yes, limitation                   No
# 10           Patient         No                     No                   No
# 11           patient         No                     No                   No
# 12           Patient         No                     No                   No
# 14           Patient         No                     No                   No
# ..               ...        ...                    ...                  ...
# 484          Patient         No     Yes, data cleaning        Yes, excluded
# 490          Patient         No  Yes, data description                   No
# 492          Patient         No                     No                   No
# 494          Patient         No                     No                   No
# 495          Patient         No                     No                   No
#
#     Rate_of_Article Include_in_Research Exclusion Reason Other_Notes  \
# 4               NaN                 Yes              NaN         NaN
# 10              NaN                 Yes              NaN         NaN
# 11              NaN                 Yes              NaN         NaN
# 12              NaN                 Yes              NaN         NaN
# 14              NaN                 Yes              NaN         NaN
# ..              ...                 ...              ...         ...
# 484             NaN                 Yes              NaN         NaN
# 490             NaN                 Yes              NaN         NaN
# 492             NaN                 Yes              NaN         NaN
# 494             NaN                 Yes              NaN         NaN
# 495             NaN                 Yes              NaN         NaN
#
#      Unnamed: 28      Epoch
# 4            NaN       2019
# 10           NaN       2019
# 11           NaN       2019
# 12           NaN       2019
# 14           NaN       2019
# ..           ...        ...
# 484          NaN  2010-2013
# 490          NaN  2010-2013
# 492          NaN  2010-2013
# 494          NaN  2010-2013
# 495          NaN  2010-2013
#
# [175 rows x 30 columns]

# %%
A_columns=['Study_Design_Type','Country/district ','Mention_Missing_Data','Handled_Missing_Data','Check_List']
groupby = 'Epoch'
mytable = TableOne(AR_Include, columns=A_columns,groupby=groupby)
mytable
mytable.to_excel('/Users/chenyuli/Research_Thesis/Validate/20210707/20210707_Table1.xlsx')
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
analytic_tools= TableOne(AR_Include, columns=['Analytic_tool'],groupby=groupby)
analytic_tools
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                     Grouped by Epoch
#                                                              Missing    Overall 2010-2013 2014-2016      2017      2018      2019
# n                                                                           175        35        35        35        35        35
# Analytic_tool, n (%) CART Salford Predictive Miner                 0    1 (0.6)   1 (2.9)
#                      Didn't mention                                   28 (16.0)  6 (17.1)  5 (14.3)  8 (22.9)   3 (8.6)  6 (17.1)
#                      EZR                                                1 (0.6)                                           1 (2.9)
#                      Excel                                              1 (0.6)                                           1 (2.9)
#                      GraphPad Prism                                     1 (0.6)                                           1 (2.9)
#                      JMP                                                1 (0.6)   1 (2.9)
#                      Mplus                                              1 (0.6)   1 (2.9)
#                      NCSS                                               1 (0.6)                                           1 (2.9)
#                      PASW Statistics 17.0                               1 (0.6)   1 (2.9)
#                      R                                                 14 (8.0)                      4 (11.4)  6 (17.1)  4 (11.4)
#                      R, SPSS                                            1 (0.6)                                 1 (2.9)
#                      SAS                                              37 (21.1)  8 (22.9)  8 (22.9)  9 (25.7)  7 (20.0)  5 (14.3)
#                      SAS, R                                             1 (0.6)                       1 (2.9)
#                      SPSS                                             36 (20.6)  8 (22.9)  9 (25.7)  6 (17.1)  8 (22.9)  5 (14.3)
#                      SPSS, Epidata                                      1 (0.6)                                           1 (2.9)
#                      SPSS, R                                            1 (0.6)                                 1 (2.9)
#                      SPSS, SAS                                          1 (0.6)                                 1 (2.9)
#                      SPSS, Statistica                                   1 (0.6)   1 (2.9)
#                      SPSS,MedCalc                                       1 (0.6)             1 (2.9)
#                      SPSS,Stata                                         1 (0.6)   1 (2.9)
#                      STATA                                              6 (3.4)             2 (5.7)  4 (11.4)
#                      STATA, SPSS                                        1 (0.6)             1 (2.9)
#                      SigmaPlot                                          1 (0.6)                                           1 (2.9)
#                      Stata                                            31 (17.7)  6 (17.1)  7 (20.0)   2 (5.7)  7 (20.0)  9 (25.7)
#                      Stata, R                                           4 (2.3)             2 (5.7)   1 (2.9)   1 (2.9)
#                      Statview                                           1 (0.6)   1 (2.9)

# %% [markdown]
# ## Step 9  Meta-regression

# %%
#pip install git+https://github.com/neurostuff/pymare.git
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import pymare
import numpy as np
from pymare import meta_regression
# Sensitivity analysis for Real-World Methods used 
# y proportion of study 
# X middle of Epoch [2011.5,2015,2017.5,2018.5,2019.5]  meta-regression with time as the independent variable- mid poiont of epoch 
# v  pq/n
# pvalue cannot reject 0, CI contains 0
# proportion of use RWM increase 3.4% per year , even use the small sample size and upper bound , 
y1 = pHat.iloc[0]# study-level estimates
v1=err_df.iloc[0]**2  # Study-level variance
X0=[2011.5,2015,2017.5,2018.5,2019.5]
X1 = [11.5,15,17.5,18.5,19.5]
X2 = [1.5,5,7.5,8.5,9.5]# 2010 

X3 = [-3.5,0,2.5,3.5,4.5]
X4=[X*X for X in X3]
X5=[]

for i in range(len(X3)):
        X5.append([X3[i],X4[i]])
# fit models 
result_RWM_0 = meta_regression(y1,v=v1,X=X0, X_names=['Real-World Methods'],add_intercept=True, method='REML')
result_RWM_1 = meta_regression(y1,v=v1,X=X1, X_names=['Real-World Methods'],add_intercept=True, method='REML')
result_RWM_2 = meta_regression(y1,v=v1,X=X2, X_names=['Real-World Methods'],add_intercept=True, method='REML')
result_RWM_3 = meta_regression(y1,v=v1,X=X3, X_names=['Real-World Methods'],add_intercept=True, method='REML')
result_RWM_4 = meta_regression(y1,v=v1,X=X5, X_names=['Real-World Methods',"square"],add_intercept=True, method='REML')
# transform results 
result_RWM_0=result_RWM_0.to_df()
result_RWM_1=result_RWM_1.to_df()
result_RWM_2=result_RWM_2.to_df()
result_RWM_3=result_RWM_3.to_df()
result_RWM_4=result_RWM_4.to_df()
# print results
print(result_RWM_3)
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                  name  estimate        se   z-score   p-value  ci_0.025  \
# 0           intercept  0.277154  0.072382  3.829069  0.000129  0.135289
# 1  Real-World Methods -0.003055  0.021632 -0.141230  0.887688 -0.045452
#
#    ci_0.975
# 0  0.419020
# 1  0.039342

# %%
rows, cols = (5, 2)
arr = [[0]*cols]*rows
arr
for i in range(len(X3)):
    arr[i]=(X3[i],X4[i])
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# sphinx_gallery_thumbnail_number = 3
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy import stats

import pymare


# A small function to make things easier later on
def var_to_ci(y, v, n):
    """Convert sampling variance to 95% CI"""
    term = 1.96 * np.sqrt(v) / np.sqrt(n)
    return y - term, y + term
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
X5
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [[-3.5, 12.25], [0, 0], [2.5, 6.25], [3.5, 12.25], [4.5, 20.25]]

# %%
result_RWM_0

# Sensitivity analysis for Sensitivity-analysis performed
y2 = pHat.iloc[1]# study-level estimates
v2=err_df.iloc[1]**2  # Study-level variance
X = [2011.5,2015,2017.5,2018.5,2019.5]
result_SA = meta_regression(y2,v=v2,X=X, X_names=['Sensitivity Analysis'],add_intercept=False,
                         method='REML')
result_SA.to_df()
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                    name  estimate        se   z-score  p-value  ci_0.025  \
# 0  Sensitivity Analysis  0.000072  0.000025  2.853779  0.00432  0.000023
#
#    ci_0.975
# 0  0.000122

# %%
# Sensitivity analysis for missing data
y3 = pHat.iloc[2]# study-level estimates
v3=err_df.iloc[2]**2  # Study-level variance
X = [11.5,15,17.5,18.5,19.5]
result_MD = meta_regression(y3,v=v3,X=X, X_names=['Missing Data'],add_intercept=True,
                         method='REML')
result_MD.to_df()
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#            name  estimate        se   z-score   p-value  ci_0.025  ci_0.975
# 0     intercept  0.294664  0.348463  0.845610  0.397770 -0.388311  0.977639
# 1  Missing Data -0.004318  0.020702 -0.208565  0.834788 -0.044893  0.036257

# %%
type(result_MD)
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# pymare.results.MetaRegressionResults

# %%
pHat
# Sensitivity analysis for Sensitivity-analysis performed
y2 = pHat.iloc[1]# study-level estimates
v2=err_df.iloc[1]**2 # Study-level variance
X = [2011.5,2015,2017.5,2018.5,2019.5]
result_test = meta_regression(y2,v=v2,X=X,add_intercept=True,
                         method='REML')
result_test.to_df()
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         name  estimate         se   z-score  p-value   ci_0.025   ci_0.975
# 0  intercept  6.424810  33.293761  0.192973  0.84698 -58.829762  71.679382
# 1          0 -0.003114   0.016510 -0.188608  0.85040  -0.035473   0.029245

# %% [markdown]
# # Weighted analysis

# %%
Method_Review=pd.read_excel('/Users/chenyuli/Research_Thesis/Validate/20210707/20210707_method_review.xlsx')
Method_Review
#Sensitivity_list=Method_Review[Method_Review.Analytic_Method_Name=='Sensitivity'].EndNote_ID
#Sensitivity_list
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      EndNote_ID  Pubmed_ID              Analytic_Method_Name  \
# 0          1230   24129480    Cox proportional hazard models
# 1          1230   24129480              Sensitivity analysis
# 2          1564   21694510              Sensitivity analysis
# 3          1564   21694510                 Statistic testing
# 4          1564   21694510  Multivariate Logistic Regression
# ..          ...        ...                               ...
# 407        4342   21801091               Logistic Regression
# 408        4342   21801091               kaplan-Meier method
# 409        4342   21801091                 statistic Testing
# 410        5790   23165956               Logistic Regression
# 411        5790   23165956            descriptive statistics
#
#      Real_World_Evidence  Year Comment
# 0                      0  2013     NaN
# 1    Real-World Evidence  2013     NaN
# 2    Real-World Evidence  2011     NaN
# 3                      0  2011     NaN
# 4                      0  2011     NaN
# ..                   ...   ...     ...
# 407                    0  2011     NaN
# 408                    0  2011     NaN
# 409                    0  2011     NaN
# 410                    0  2013     NaN
# 411                    0  2013     NaN
#
# [412 rows x 6 columns]

# %%
HM_list=Article_Review[(Article_Review.Include_in_Research=='Yes')&(Article_Review.Mention_Missing_Data!="No")].EndNote_Index
HM_list
# Out:
# /Users/chenyuli/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 4      3197
# 17     1449
# 19     3576
# 20     4966
# 21     4012
#        ...
# 458    3743
# 468    5219
# 480    5792
# 484    4917
# 490    5805
# Name: EndNote_Index, Length: 81, dtype: int64
